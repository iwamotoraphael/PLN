# %% [markdown]
# # EP1 de Processamento de Língua Natural - Grid Search

# %% [markdown]
# ## Leitura e análise dos dados

# %%
import pandas as pd
import numpy as np
import time
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline

# %%
treino_dataset = pd.read_excel(io='../data/ep1_esic2023_clareza_TRAIN.xlsx')
treino_dataset
# Out:
#                                               resp_text clarity
# 0       Prezado Sr Jose Taunai  Em atenção ao seu pe...      c5
# 1      "A pedido do Pró-Reitor de Graduação, informa...      c5
# 2      "Prezado (a) Sr. (a), Agradecemos o contato e...    c234
# 3      "Prezado (a) Sr. (a), Agradecemos o contato e...    c234
# 4      "Prezado Prof. Gilberto Tadeu Reis da Silva  ...    c234
# ...                                                 ...     ...
# 5995   Trata-se de solicitação com base na Lei de Ac...      c1
# 5996   Trata-se de uma solicitação repetida. As info...      c5
# 5997                                           Unidade:      c5
# 5998   Vale dizer que a gestão dos Telefones de Uso ...    c234
# 5999   WILHAN DONIZETE GONçALVES NUNES, neste NUP 23...    c234
#
# [6000 rows x 2 columns]

# %% [markdown]
# ## Modelos

# %%
X = treino_dataset.resp_text
Y = treino_dataset.clarity

# %%
def print_results(grid_search):
    best_params = grid_search.best_params_
    best_estimator = grid_search.best_estimator_

    mean_accuracy = cross_val_score(best_estimator, X, Y, scoring='accuracy', cv=10).mean()

    print("Best Parameters:", best_params)
    print("Best Mean Accuracy:", mean_accuracy)

# %% [markdown]
# ### Regressão Logística

# %% [markdown]
# #### Count Vectorizer

# %%
pipeline_logistic_count = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('clf', LogisticRegression(max_iter=9999))
])

param_grid_logistic_count = {
    'vectorizer__max_features': [5000, None],
    'vectorizer__lowercase': [True, False],
    'clf__C': [0.001, 0.01, 0.1, 0.5, 1.0, 5.0, 10.0],
    'clf__class_weight': ['balanced', None],
    'clf__penalty': ['l1', 'l2'],
    'clf__solver': ['lbfgs', 'liblinear']
}

grid_search = GridSearchCV(pipeline_logistic_count, param_grid_logistic_count, cv=10, scoring='accuracy', n_jobs=3, verbose=10)

grid_search.fit(X, Y)

print_results(grid_search)
# Out:
# Fitting 10 folds for each of 224 candidates, totalling 2240 fits
# [CV 2/10; 1/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 3/10; 1/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 1/10; 1/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 1/10; 1/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 3/10; 1/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 2/10; 1/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 4/10; 1/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 5/10; 1/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 6/10; 1/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 4/10; 1/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 7/10; 1/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 5/10; 1/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 6/10; 1/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 8/10; 1/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 9/10; 1/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 7/10; 1/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 10/10; 1/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 8/10; 1/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 9/10; 1/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 1/10; 2/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 2/10; 2/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 10/10; 1/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 3/10; 2/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 1/10; 2/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 2/10; 2/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 4/10; 2/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 5/10; 2/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 3/10; 2/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 6/10; 2/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 4/10; 2/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 5/10; 2/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 7/10; 2/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 8/10; 2/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 6/10; 2/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 9/10; 2/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 8/10; 2/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 7/10; 2/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 10/10; 2/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 1/10; 3/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 9/10; 2/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 2/10; 3/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 10/10; 2/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 1/10; 3/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 3/10; 3/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 4/10; 3/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 2/10; 3/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 5/10; 3/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 3/10; 3/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 4/10; 3/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 6/10; 3/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 7/10; 3/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 5/10; 3/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 8/10; 3/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 6/10; 3/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 7/10; 3/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 9/10; 3/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 10/10; 3/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 8/10; 3/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 1/10; 4/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 9/10; 3/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 2/10; 4/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 10/10; 3/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 3/10; 4/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 1/10; 4/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 4/10; 4/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 2/10; 4/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 5/10; 4/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 3/10; 4/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 6/10; 4/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 4/10; 4/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 7/10; 4/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 5/10; 4/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 6/10; 4/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 8/10; 4/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 9/10; 4/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 7/10; 4/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 10/10; 4/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 8/10; 4/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 1/10; 5/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 9/10; 4/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 2/10; 5/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 10/10; 4/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 3/10; 5/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 1/10; 5/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.348 total time=   0.4s
# [CV 4/10; 5/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 2/10; 5/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.327 total time=   0.4s
# [CV 5/10; 5/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 3/10; 5/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.327 total time=   0.4s
# [CV 6/10; 5/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 4/10; 5/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.335 total time=   0.4s
# [CV 7/10; 5/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 5/10; 5/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.322 total time=   0.4s
# [CV 8/10; 5/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 6/10; 5/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.352 total time=   0.4s
# [CV 9/10; 5/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 7/10; 5/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.330 total time=   0.4s
# [CV 10/10; 5/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 8/10; 5/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.322 total time=   0.4s
# [CV 1/10; 6/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 9/10; 5/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.337 total time=   0.4s
# [CV 2/10; 6/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 10/10; 5/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.323 total time=   0.3s
# [CV 3/10; 6/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 1/10; 6/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.348 total time=   0.4s
# [CV 4/10; 6/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 2/10; 6/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.327 total time=   0.4s
# [CV 5/10; 6/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 3/10; 6/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.327 total time=   0.4s
# [CV 6/10; 6/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 4/10; 6/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.335 total time=   0.4s
# [CV 7/10; 6/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 5/10; 6/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.322 total time=   0.4s
# [CV 8/10; 6/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 6/10; 6/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.352 total time=   0.4s
# [CV 9/10; 6/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 7/10; 6/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.330 total time=   0.4s
# [CV 10/10; 6/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 8/10; 6/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.322 total time=   0.4s
# [CV 1/10; 7/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 9/10; 6/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.337 total time=   0.4s
# [CV 2/10; 7/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 10/10; 6/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.323 total time=   0.4s
# [CV 3/10; 7/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 1/10; 7/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.350 total time=   0.4s
# [CV 4/10; 7/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 2/10; 7/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.323 total time=   0.4s
# [CV 5/10; 7/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 3/10; 7/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.330 total time=   0.4s
# [CV 6/10; 7/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 4/10; 7/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.377 total time=   0.4s
# [CV 7/10; 7/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 5/10; 7/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.315 total time=   0.4s
# [CV 8/10; 7/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 6/10; 7/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.352 total time=   0.4s
# [CV 9/10; 7/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 7/10; 7/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.325 total time=   0.3s
# [CV 10/10; 7/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 8/10; 7/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.322 total time=   0.3s
# [CV 1/10; 8/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 9/10; 7/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.340 total time=   0.3s
# [CV 2/10; 8/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 10/10; 7/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.322 total time=   0.3s
# [CV 3/10; 8/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 1/10; 8/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.350 total time=   0.4s
# [CV 2/10; 8/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.323 total time=   0.4s
# [CV 4/10; 8/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 5/10; 8/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 3/10; 8/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.330 total time=   0.4s
# [CV 6/10; 8/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 4/10; 8/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.377 total time=   0.4s
# [CV 5/10; 8/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.315 total time=   0.4s
# [CV 7/10; 8/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 8/10; 8/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 6/10; 8/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.352 total time=   0.4s
# [CV 9/10; 8/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 7/10; 8/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.325 total time=   0.4s
# [CV 8/10; 8/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.322 total time=   0.4s
# [CV 10/10; 8/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 1/10; 9/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 9/10; 8/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.340 total time=   0.4s
# [CV 2/10; 9/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 10/10; 8/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.322 total time=   0.3s
# [CV 3/10; 9/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 1/10; 9/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.450 total time=   0.7s
# [CV 4/10; 9/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 2/10; 9/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.505 total time=   0.7s
# [CV 5/10; 9/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 3/10; 9/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.417 total time=   0.7s
# [CV 6/10; 9/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 4/10; 9/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.448 total time=   0.8s
# [CV 7/10; 9/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 5/10; 9/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.440 total time=   0.7s
# [CV 8/10; 9/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 6/10; 9/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.443 total time=   0.7s
# [CV 9/10; 9/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 7/10; 9/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.337 total time=   0.6s
# [CV 10/10; 9/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 8/10; 9/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.433 total time=   0.6s
# [CV 1/10; 10/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 9/10; 9/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.457 total time=   0.7s
# [CV 2/10; 10/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 10/10; 9/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.453 total time=   0.6s
# [CV 3/10; 10/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 1/10; 10/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.455 total time=   1.2s
# [CV 4/10; 10/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 2/10; 10/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.505 total time=   1.1s
# [CV 5/10; 10/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 3/10; 10/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.418 total time=   1.2s
# [CV 6/10; 10/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 5/10; 10/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.440 total time=   1.0s
# [CV 7/10; 10/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 4/10; 10/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.445 total time=   1.2s
# [CV 8/10; 10/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 6/10; 10/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.443 total time=   1.1s
# [CV 9/10; 10/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 8/10; 10/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.432 total time=   1.0s
# [CV 10/10; 10/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 7/10; 10/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.337 total time=   1.1s
# [CV 1/10; 11/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 9/10; 10/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.458 total time=   1.1s
# [CV 2/10; 11/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 1/10; 11/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.438 total time=   0.7s
# [CV 3/10; 11/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 10/10; 10/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.457 total time=   1.1s
# [CV 4/10; 11/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 2/10; 11/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.528 total time=   0.7s
# [CV 5/10; 11/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 3/10; 11/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.417 total time=   0.7s
# [CV 6/10; 11/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 4/10; 11/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.447 total time=   0.7s
# [CV 7/10; 11/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 5/10; 11/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.447 total time=   0.6s
# [CV 8/10; 11/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 6/10; 11/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.447 total time=   0.6s
# [CV 9/10; 11/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 7/10; 11/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.332 total time=   0.6s
# [CV 10/10; 11/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 8/10; 11/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.437 total time=   0.6s
# [CV 1/10; 12/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 9/10; 11/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.458 total time=   0.6s
# [CV 2/10; 12/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 10/10; 11/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.460 total time=   0.7s
# [CV 3/10; 12/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 1/10; 12/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.442 total time=   1.2s
# [CV 4/10; 12/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 2/10; 12/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.528 total time=   1.2s
# [CV 5/10; 12/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 3/10; 12/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.415 total time=   1.3s
# [CV 6/10; 12/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 4/10; 12/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.447 total time=   1.2s
# [CV 7/10; 12/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 5/10; 12/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.447 total time=   1.2s
# [CV 8/10; 12/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 6/10; 12/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.445 total time=   1.2s
# [CV 9/10; 12/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 8/10; 12/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.435 total time=   1.1s
# [CV 10/10; 12/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 7/10; 12/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.335 total time=   1.2s
# [CV 1/10; 13/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 1/10; 13/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.482 total time=   0.4s
# [CV 2/10; 13/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 9/10; 12/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.462 total time=   1.2s
# [CV 3/10; 13/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 2/10; 13/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.502 total time=   0.4s
# [CV 4/10; 13/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 3/10; 13/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.420 total time=   0.4s
# [CV 5/10; 13/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 10/10; 12/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.462 total time=   1.2s
# [CV 6/10; 13/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 4/10; 13/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.463 total time=   0.4s
# [CV 7/10; 13/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 5/10; 13/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.442 total time=   0.4s
# [CV 8/10; 13/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 6/10; 13/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.427 total time=   0.4s
# [CV 9/10; 13/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 7/10; 13/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.342 total time=   0.4s
# [CV 10/10; 13/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 8/10; 13/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.400 total time=   0.4s
# [CV 1/10; 14/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 9/10; 13/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.468 total time=   0.4s
# [CV 2/10; 14/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 10/10; 13/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.483 total time=   0.4s
# [CV 3/10; 14/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 1/10; 14/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.482 total time=   0.4s
# [CV 4/10; 14/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 2/10; 14/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.502 total time=   0.4s
# [CV 5/10; 14/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 3/10; 14/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.422 total time=   0.4s
# [CV 6/10; 14/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 4/10; 14/224] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.465 total time=   0.5s
# [CV 7/10; 14/224] START clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# ...
# [CV 10/10; 221/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000
# [CV 8/10; 221/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.370 total time=   3.2s
# [CV 1/10; 222/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 10/10; 221/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.477 total time=   3.3s
# [CV 2/10; 222/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 9/10; 221/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=5000;, score=0.417 total time=   3.8s
# [CV 3/10; 222/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 1/10; 222/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.438 total time=   4.1s
# [CV 4/10; 222/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 2/10; 222/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.482 total time=   4.8s
# [CV 5/10; 222/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 3/10; 222/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.427 total time=   4.7s
# [CV 6/10; 222/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 4/10; 222/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.400 total time=   4.3s
# [CV 7/10; 222/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 6/10; 222/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.462 total time=   3.8s
# [CV 8/10; 222/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 5/10; 222/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.440 total time=   5.0s
# [CV 9/10; 222/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 7/10; 222/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.370 total time=   3.9s
# [CV 10/10; 222/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None
# [CV 8/10; 222/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.375 total time=   4.0s
# [CV 1/10; 223/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 9/10; 222/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.467 total time=   5.4s
# [CV 2/10; 223/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 10/10; 222/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=True, vectorizer__max_features=None;, score=0.488 total time=   4.2s
# [CV 3/10; 223/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 1/10; 223/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.425 total time=   3.7s
# [CV 4/10; 223/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 3/10; 223/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.408 total time=   2.9s
# [CV 5/10; 223/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 2/10; 223/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.465 total time=   3.4s
# [CV 6/10; 223/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 4/10; 223/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.412 total time=   3.2s
# [CV 7/10; 223/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 5/10; 223/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.432 total time=   3.4s
# [CV 8/10; 223/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 6/10; 223/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.468 total time=   3.3s
# [CV 9/10; 223/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 7/10; 223/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.355 total time=   2.7s
# [CV 10/10; 223/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000
# [CV 8/10; 223/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.383 total time=   3.0s
# [CV 1/10; 224/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 9/10; 223/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.448 total time=   3.4s
# [CV 2/10; 224/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 10/10; 223/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=5000;, score=0.463 total time=   3.0s
# [CV 3/10; 224/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 3/10; 224/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.422 total time=   4.5s
# [CV 4/10; 224/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 2/10; 224/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.485 total time=   5.0s
# [CV 5/10; 224/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 1/10; 224/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.425 total time=   5.9s
# [CV 6/10; 224/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 4/10; 224/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.417 total time=   4.4s
# [CV 7/10; 224/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 6/10; 224/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.475 total time=   4.5s
# [CV 8/10; 224/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 5/10; 224/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.448 total time=   5.1s
# [CV 9/10; 224/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 7/10; 224/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.375 total time=   3.9s
# [CV 10/10; 224/224] START clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None
# [CV 8/10; 224/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.387 total time=   4.4s
# [CV 9/10; 224/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.487 total time=   5.0s
# [CV 10/10; 224/224] END clf__C=10.0, clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, vectorizer__lowercase=False, vectorizer__max_features=None;, score=0.465 total time=   3.5s
# /opt/homebrew/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 560 fits failed out of a total of 2240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 560 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/pipeline.py", line 427, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/homebrew/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan 0.33216667 0.33216667
#  0.3355     0.3355     0.43833333 0.439      0.441      0.44166667
#  0.44283333 0.44316667 0.4485     0.4485            nan        nan
#         nan        nan 0.33216667 0.33216667 0.3355     0.3355
#  0.43833333 0.439      0.441      0.44166667 0.44283333 0.44316667
#  0.4485     0.4485            nan        nan        nan        nan
#  0.421      0.4215     0.42866667 0.42866667 0.4465     0.44866667
#  0.44283333 0.44866667 0.445      0.44683333 0.445      0.44933333
#         nan        nan        nan        nan 0.42133333 0.42116667
#  0.42883333 0.42933333 0.4465     0.44866667 0.44283333 0.44866667
#  0.445      0.44683333 0.445      0.44933333        nan        nan
#         nan        nan 0.42733333 0.42733333 0.42133333 0.42133333
#  0.44516667 0.4435     0.43666667 0.44183333 0.4435     0.446
#  0.44066667 0.44783333        nan        nan        nan        nan
#  0.42766667 0.42716667 0.42133333 0.42133333 0.44516667 0.4435
#  0.43666667 0.44183333 0.4435     0.446      0.44066667 0.44783333
#         nan        nan        nan        nan 0.442      0.444
#  0.435      0.43783333 0.43133333 0.43883333 0.42883333 0.43883333
#  0.435      0.44133333 0.4325     0.446             nan        nan
#         nan        nan 0.442      0.44366667 0.435      0.43783333
#  0.43133333 0.43883333 0.42883333 0.43883333 0.435      0.44133333
#  0.4325     0.446             nan        nan        nan        nan
#  0.43216667 0.433      0.43133333 0.43433333 0.43183333 0.436
#  0.42933333 0.437      0.43066667 0.43266667 0.4295     0.4405
#         nan        nan        nan        nan 0.43233333 0.43283333
#  0.4315     0.43433333 0.43183333 0.436      0.42933333 0.437
#  0.43066667 0.43266667 0.4295     0.4405            nan        nan
#         nan        nan 0.42616667 0.4245     0.42466667 0.42716667
#  0.42933333 0.43183333 0.4235     0.43166667 0.42383333 0.434
#  0.42633333 0.43966667        nan        nan        nan        nan
#  0.42583333 0.42466667 0.42516667 0.427      0.42933333 0.43183333
#  0.4235     0.43166667 0.42383333 0.434      0.42633333 0.43966667
#         nan        nan        nan        nan 0.42966667 0.42366667
#  0.4235     0.43033333 0.426      0.42983333 0.42066667 0.432
#  0.42333333 0.43483333 0.426      0.4385            nan        nan
#         nan        nan 0.42983333 0.424      0.42333333 0.4305
#  0.426      0.42983333 0.42066667 0.432      0.42333333 0.43483333
#  0.426      0.4385    ]
#   warnings.warn(
# Best Parameters: {'clf__C': 0.01, 'clf__class_weight': 'balanced', 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vectorizer__lowercase': False, 'vectorizer__max_features': None}
# Best Mean Accuracy: 0.4493333333333333

# %% [markdown]
# #### TF-IDF Vectorizer

# %%
pipeline_logistic_tfidf = Pipeline([
    ('vectorizer', TfidfVectorizer()),
    ('clf', LogisticRegression(max_iter=9999))
])

param_grid_logistic_tfidf = {
    'vectorizer__max_features': [5000, None],
    'vectorizer__lowercase': [True, False],
    'clf__C': [0.001, 0.01, 0.1, 0.5, 1.0, 5.0, 10.0],
    'clf__class_weight': ['balanced', None],
    'clf__penalty': ['l1', 'l2'],
    'clf__solver': ['lbfgs', 'liblinear']
}

grid_search_logistic_tfidf = GridSearchCV(pipeline_logistic_tfidf, param_grid_logistic_tfidf, cv=5, scoring='accuracy', n_jobs=1, verbose=10)

grid_search_logistic_tfidf.fit(X, Y)

print_results(grid_search_logistic_tfidf)

# %% [markdown]
# #### TF-IDF Vectorizer Bigramas

# %%
pipeline_logistic_tfidf_bigram = Pipeline([
    ('vectorizer', TfidfVectorizer(ngram_range=(2,2))),
    ('clf', LogisticRegression(max_iter=9999))
])

param_grid_logistic_tfidf_bigram = {
    'vectorizer__max_features': [5000, None],
    'vectorizer__lowercase': [True, False],
    'clf__C': [0.001, 0.01, 0.1, 0.5, 1.0, 5.0, 10.0],
    'clf__class_weight': ['balanced', None],
    'clf__penalty': ['l1', 'l2'],
    'clf__solver': ['lbfgs', 'liblinear']
}

grid_search_logistic_tfidf_bigram = GridSearchCV(pipeline_logistic_tfidf_bigram, param_grid_logistic_tfidf_bigram, cv=5, scoring='accuracy', n_jobs=1, verbose=10)

grid_search_logistic_tfidf_bigram.fit(X, Y)

print_results(grid_search_logistic_tfidf_bigram)

# %% [markdown]
# #### TF-IDF Vectorizer 3-Char

# %%
pipeline_logistic_tfidf_3char = Pipeline([
    ('vectorizer', TfidfVectorizer(analyzer='char', ngram_range=(3,3))),
    ('clf', LogisticRegression(max_iter=9999))
])

param_grid_logistic_tfidf_3char = {
    'vectorizer__max_features': [5000, None],
    'vectorizer__lowercase': [True, False],
    'clf__C': [0.001, 0.01, 0.1, 0.5, 1.0, 5.0, 10.0],
    'clf__class_weight': ['balanced', None],
    'clf__penalty': ['l1', 'l2'],
    'clf__solver': ['lbfgs', 'liblinear']
}

grid_search_logistic_tfidf_3char = GridSearchCV(pipeline_logistic_tfidf_3char, param_grid_logistic_tfidf_3char, cv=5, scoring='accuracy', n_jobs=1, verbose=10)

grid_search_logistic_tfidf_3char.fit(X, Y)

print_results(grid_search_logistic_tfidf_3char)

# %% [markdown]
# #### TF-IDF Vectorizer 5-Char

# %%
pipeline_logistic_tfidf_5char = Pipeline([
    ('vectorizer', TfidfVectorizer(analyzer='char', ngram_range=(5,5))),
    ('clf', LogisticRegression(max_iter=9999))
])

param_grid_logistic_tfidf_5char = {
    'vectorizer__max_features': [5000, None],
    'vectorizer__lowercase': [True, False],
    'clf__C': [0.001, 0.01, 0.1, 0.5, 1.0, 5.0, 10.0],
    'clf__class_weight': ['balanced', None],
    'clf__penalty': ['l1', 'l2'],
    'clf__solver': ['lbfgs', 'liblinear']
}

grid_search_logistic_tfidf_5char = GridSearchCV(pipeline_logistic_tfidf_5char, param_grid_logistic_tfidf_5char, cv=5, scoring='accuracy', n_jobs=1, verbose=10)

grid_search_logistic_tfidf_5char.fit(X, Y)

print_results(grid_search_logistic_tfidf_5char)

# %% [markdown]
# # Rascunho

# %%
c_list = np.geomspace(0.01, 1.0, 20)

pipeline = Pipeline([
    ('vectorizer', CountVectorizer(max_features=None)),
    ('clf', LogisticRegression(max_iter=9999))
])

param_grid = {
    'clf__C': c_list,
}

grid_search = GridSearchCV(pipeline, param_grid, cv=10, scoring='accuracy', n_jobs=4, verbose=10)

grid_search.fit(X, Y)

best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

# Calculate the mean accuracy using cross-validation
mean_accuracy = cross_val_score(best_estimator, X, Y, scoring='accuracy', cv=10).mean()

print("Best Parameters:", best_params)
print("Best Mean Accuracy:", mean_accuracy)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [CV 3/10; 1/20] START clf__C=0.01...............................................
# [CV 4/10; 1/20] START clf__C=0.01...............................................
# [CV 2/10; 1/20] START clf__C=0.01...............................................
# [CV 1/10; 1/20] START clf__C=0.01...............................................
# [CV 4/10; 1/20] END ................clf__C=0.01;, score=0.453 total time=   2.0s
# [CV 5/10; 1/20] START clf__C=0.01...............................................
# [CV 2/10; 1/20] END ................clf__C=0.01;, score=0.518 total time=   2.1s
# [CV 6/10; 1/20] START clf__C=0.01...............................................
# [CV 3/10; 1/20] END ................clf__C=0.01;, score=0.427 total time=   2.1s
# [CV 7/10; 1/20] START clf__C=0.01...............................................
# [CV 1/10; 1/20] END ................clf__C=0.01;, score=0.450 total time=   2.3s
# [CV 8/10; 1/20] START clf__C=0.01...............................................
# [CV 5/10; 1/20] END ................clf__C=0.01;, score=0.453 total time=   1.9s
# [CV 9/10; 1/20] START clf__C=0.01...............................................
# [CV 6/10; 1/20] END ................clf__C=0.01;, score=0.447 total time=   2.1s
# [CV 10/10; 1/20] START clf__C=0.01..............................................
# [CV 7/10; 1/20] END ................clf__C=0.01;, score=0.362 total time=   2.2s
# [CV 1/10; 2/20] START clf__C=0.012742749857031334...............................
# [CV 8/10; 1/20] END ................clf__C=0.01;, score=0.403 total time=   2.1s
# [CV 2/10; 2/20] START clf__C=0.012742749857031334...............................
# [CV 9/10; 1/20] END ................clf__C=0.01;, score=0.467 total time=   2.2s
# [CV 3/10; 2/20] START clf__C=0.012742749857031334...............................
# [CV 10/10; 1/20] END ...............clf__C=0.01;, score=0.507 total time=   2.2s
# [CV 4/10; 2/20] START clf__C=0.012742749857031334...............................
# [CV 2/10; 2/20] END clf__C=0.012742749857031334;, score=0.518 total time=   2.2s
# [CV 5/10; 2/20] START clf__C=0.012742749857031334...............................
# [CV 1/10; 2/20] END clf__C=0.012742749857031334;, score=0.457 total time=   2.4s
# [CV 6/10; 2/20] START clf__C=0.012742749857031334...............................
# [CV 3/10; 2/20] END clf__C=0.012742749857031334;, score=0.432 total time=   2.1s
# [CV 7/10; 2/20] START clf__C=0.012742749857031334...............................
# [CV 4/10; 2/20] END clf__C=0.012742749857031334;, score=0.452 total time=   2.0s
# [CV 8/10; 2/20] START clf__C=0.012742749857031334...............................
# [CV 5/10; 2/20] END clf__C=0.012742749857031334;, score=0.443 total time=   2.2s
# [CV 6/10; 2/20] END clf__C=0.012742749857031334;, score=0.452 total time=   2.0s
# [CV 9/10; 2/20] START clf__C=0.012742749857031334...............................
# [CV 10/10; 2/20] START clf__C=0.012742749857031334..............................
# [CV 7/10; 2/20] END clf__C=0.012742749857031334;, score=0.357 total time=   2.1s
# [CV 1/10; 3/20] START clf__C=0.016237767391887217...............................
# [CV 8/10; 2/20] END clf__C=0.012742749857031334;, score=0.398 total time=   2.1s
# [CV 2/10; 3/20] START clf__C=0.016237767391887217...............................
# [CV 9/10; 2/20] END clf__C=0.012742749857031334;, score=0.465 total time=   2.2s
# [CV 3/10; 3/20] START clf__C=0.016237767391887217...............................
# [CV 10/10; 2/20] END clf__C=0.012742749857031334;, score=0.503 total time=   2.3s
# [CV 4/10; 3/20] START clf__C=0.016237767391887217...............................
# [CV 2/10; 3/20] END clf__C=0.016237767391887217;, score=0.522 total time=   2.4s
# [CV 5/10; 3/20] START clf__C=0.016237767391887217...............................
# [CV 1/10; 3/20] END clf__C=0.016237767391887217;, score=0.458 total time=   2.6s
# [CV 6/10; 3/20] START clf__C=0.016237767391887217...............................
# [CV 3/10; 3/20] END clf__C=0.016237767391887217;, score=0.432 total time=   2.2s
# [CV 7/10; 3/20] START clf__C=0.016237767391887217...............................
# [CV 4/10; 3/20] END clf__C=0.016237767391887217;, score=0.442 total time=   2.3s
# [CV 8/10; 3/20] START clf__C=0.016237767391887217...............................
# [CV 5/10; 3/20] END clf__C=0.016237767391887217;, score=0.450 total time=   2.2s
# [CV 9/10; 3/20] START clf__C=0.016237767391887217...............................
# [CV 6/10; 3/20] END clf__C=0.016237767391887217;, score=0.443 total time=   2.3s
# [CV 10/10; 3/20] START clf__C=0.016237767391887217..............................
# [CV 7/10; 3/20] END clf__C=0.016237767391887217;, score=0.358 total time=   2.4s
# [CV 1/10; 4/20] START clf__C=0.0206913808111479.................................
# [CV 8/10; 3/20] END clf__C=0.016237767391887217;, score=0.398 total time=   2.4s
# [CV 2/10; 4/20] START clf__C=0.0206913808111479.................................
# [CV 9/10; 3/20] END clf__C=0.016237767391887217;, score=0.467 total time=   2.4s
# [CV 3/10; 4/20] START clf__C=0.0206913808111479.................................
# [CV 10/10; 3/20] END clf__C=0.016237767391887217;, score=0.505 total time=   2.4s
# [CV 4/10; 4/20] START clf__C=0.0206913808111479.................................
# [CV 1/10; 4/20] END ..clf__C=0.0206913808111479;, score=0.455 total time=   2.7s
# [CV 5/10; 4/20] START clf__C=0.0206913808111479.................................
# [CV 2/10; 4/20] END ..clf__C=0.0206913808111479;, score=0.520 total time=   2.5s
# [CV 6/10; 4/20] START clf__C=0.0206913808111479.................................
# [CV 3/10; 4/20] END ..clf__C=0.0206913808111479;, score=0.430 total time=   2.6s
# [CV 7/10; 4/20] START clf__C=0.0206913808111479.................................
# [CV 4/10; 4/20] END ..clf__C=0.0206913808111479;, score=0.428 total time=   2.5s
# [CV 8/10; 4/20] START clf__C=0.0206913808111479.................................
# [CV 5/10; 4/20] END ..clf__C=0.0206913808111479;, score=0.442 total time=   2.5s
# [CV 9/10; 4/20] START clf__C=0.0206913808111479.................................
# [CV 6/10; 4/20] END ..clf__C=0.0206913808111479;, score=0.442 total time=   2.5s
# [CV 10/10; 4/20] START clf__C=0.0206913808111479................................
# [CV 7/10; 4/20] END ..clf__C=0.0206913808111479;, score=0.358 total time=   2.5s
# [CV 1/10; 5/20] START clf__C=0.026366508987303583...............................
# [CV 8/10; 4/20] END ..clf__C=0.0206913808111479;, score=0.393 total time=   2.5s
# [CV 2/10; 5/20] START clf__C=0.026366508987303583...............................
# [CV 9/10; 4/20] END ..clf__C=0.0206913808111479;, score=0.462 total time=   2.6s
# [CV 3/10; 5/20] START clf__C=0.026366508987303583...............................
# [CV 10/10; 4/20] END .clf__C=0.0206913808111479;, score=0.503 total time=   2.6s
# [CV 4/10; 5/20] START clf__C=0.026366508987303583...............................
# [CV 1/10; 5/20] END clf__C=0.026366508987303583;, score=0.452 total time=   2.7s
# [CV 5/10; 5/20] START clf__C=0.026366508987303583...............................
# [CV 2/10; 5/20] END clf__C=0.026366508987303583;, score=0.530 total time=   2.9s
# [CV 6/10; 5/20] START clf__C=0.026366508987303583...............................
# [CV 3/10; 5/20] END clf__C=0.026366508987303583;, score=0.433 total time=   2.8s
# [CV 7/10; 5/20] START clf__C=0.026366508987303583...............................
# [CV 4/10; 5/20] END clf__C=0.026366508987303583;, score=0.430 total time=   2.7s
# [CV 8/10; 5/20] START clf__C=0.026366508987303583...............................
# [CV 5/10; 5/20] END clf__C=0.026366508987303583;, score=0.440 total time=   2.7s
# [CV 9/10; 5/20] START clf__C=0.026366508987303583...............................
# [CV 6/10; 5/20] END clf__C=0.026366508987303583;, score=0.452 total time=   2.7s
# [CV 10/10; 5/20] START clf__C=0.026366508987303583..............................
# [CV 7/10; 5/20] END clf__C=0.026366508987303583;, score=0.362 total time=   2.8s
# [CV 1/10; 6/20] START clf__C=0.03359818286283781................................
# [CV 8/10; 5/20] END clf__C=0.026366508987303583;, score=0.395 total time=   2.7s
# [CV 2/10; 6/20] START clf__C=0.03359818286283781................................
# [CV 9/10; 5/20] END clf__C=0.026366508987303583;, score=0.458 total time=   2.7s
# [CV 3/10; 6/20] START clf__C=0.03359818286283781................................
# [CV 10/10; 5/20] END clf__C=0.026366508987303583;, score=0.505 total time=   2.6s
# [CV 4/10; 6/20] START clf__C=0.03359818286283781................................
# [CV 2/10; 6/20] END .clf__C=0.03359818286283781;, score=0.525 total time=   2.6s
# [CV 5/10; 6/20] START clf__C=0.03359818286283781................................
# [CV 1/10; 6/20] END .clf__C=0.03359818286283781;, score=0.453 total time=   3.0s
# [CV 6/10; 6/20] START clf__C=0.03359818286283781................................
# [CV 3/10; 6/20] END .clf__C=0.03359818286283781;, score=0.427 total time=   3.1s
# [CV 7/10; 6/20] START clf__C=0.03359818286283781................................
# [CV 4/10; 6/20] END .clf__C=0.03359818286283781;, score=0.430 total time=   2.8s
# [CV 8/10; 6/20] START clf__C=0.03359818286283781................................
# [CV 5/10; 6/20] END .clf__C=0.03359818286283781;, score=0.442 total time=   2.7s
# [CV 9/10; 6/20] START clf__C=0.03359818286283781................................
# [CV 6/10; 6/20] END .clf__C=0.03359818286283781;, score=0.457 total time=   3.1s
# [CV 10/10; 6/20] START clf__C=0.03359818286283781...............................
# [CV 7/10; 6/20] END .clf__C=0.03359818286283781;, score=0.363 total time=   2.8s
# [CV 1/10; 7/20] START clf__C=0.04281332398719394................................
# [CV 8/10; 6/20] END .clf__C=0.03359818286283781;, score=0.380 total time=   3.1s
# [CV 2/10; 7/20] START clf__C=0.04281332398719394................................
# [CV 9/10; 6/20] END .clf__C=0.03359818286283781;, score=0.460 total time=   2.8s
# [CV 3/10; 7/20] START clf__C=0.04281332398719394................................
# [CV 10/10; 6/20] END clf__C=0.03359818286283781;, score=0.513 total time=   3.0s
# [CV 4/10; 7/20] START clf__C=0.04281332398719394................................
# [CV 1/10; 7/20] END .clf__C=0.04281332398719394;, score=0.453 total time=   3.1s
# [CV 5/10; 7/20] START clf__C=0.04281332398719394................................
# [CV 2/10; 7/20] END .clf__C=0.04281332398719394;, score=0.527 total time=   3.1s
# [CV 6/10; 7/20] START clf__C=0.04281332398719394................................
# [CV 3/10; 7/20] END .clf__C=0.04281332398719394;, score=0.440 total time=   3.2s
# [CV 7/10; 7/20] START clf__C=0.04281332398719394................................
# [CV 4/10; 7/20] END .clf__C=0.04281332398719394;, score=0.432 total time=   3.2s
# [CV 8/10; 7/20] START clf__C=0.04281332398719394................................
# [CV 5/10; 7/20] END .clf__C=0.04281332398719394;, score=0.450 total time=   2.9s
# [CV 9/10; 7/20] START clf__C=0.04281332398719394................................
# [CV 6/10; 7/20] END .clf__C=0.04281332398719394;, score=0.463 total time=   2.8s
# [CV 10/10; 7/20] START clf__C=0.04281332398719394...............................
# [CV 7/10; 7/20] END .clf__C=0.04281332398719394;, score=0.372 total time=   2.9s
# [CV 1/10; 8/20] START clf__C=0.0545559478116852.................................
# [CV 8/10; 7/20] END .clf__C=0.04281332398719394;, score=0.377 total time=   3.1s
# [CV 2/10; 8/20] START clf__C=0.0545559478116852.................................
# [CV 9/10; 7/20] END .clf__C=0.04281332398719394;, score=0.472 total time=   3.2s
# [CV 3/10; 8/20] START clf__C=0.0545559478116852.................................
# [CV 10/10; 7/20] END clf__C=0.04281332398719394;, score=0.513 total time=   3.1s
# [CV 4/10; 8/20] START clf__C=0.0545559478116852.................................
# [CV 1/10; 8/20] END ..clf__C=0.0545559478116852;, score=0.465 total time=   3.5s
# [CV 5/10; 8/20] START clf__C=0.0545559478116852.................................
# [CV 2/10; 8/20] END ..clf__C=0.0545559478116852;, score=0.525 total time=   3.2s
# [CV 6/10; 8/20] START clf__C=0.0545559478116852.................................
# [CV 3/10; 8/20] END ..clf__C=0.0545559478116852;, score=0.438 total time=   3.5s
# [CV 7/10; 8/20] START clf__C=0.0545559478116852.................................
# [CV 4/10; 8/20] END ..clf__C=0.0545559478116852;, score=0.428 total time=   3.3s
# [CV 8/10; 8/20] START clf__C=0.0545559478116852.................................
# [CV 5/10; 8/20] END ..clf__C=0.0545559478116852;, score=0.443 total time=   3.2s
# [CV 9/10; 8/20] START clf__C=0.0545559478116852.................................
# [CV 6/10; 8/20] END ..clf__C=0.0545559478116852;, score=0.465 total time=   3.2s
# [CV 10/10; 8/20] START clf__C=0.0545559478116852................................
# [CV 7/10; 8/20] END ..clf__C=0.0545559478116852;, score=0.378 total time=   3.2s
# [CV 1/10; 9/20] START clf__C=0.06951927961775606................................
# [CV 8/10; 8/20] END ..clf__C=0.0545559478116852;, score=0.377 total time=   3.2s
# [CV 2/10; 9/20] START clf__C=0.06951927961775606................................
# [CV 9/10; 8/20] END ..clf__C=0.0545559478116852;, score=0.467 total time=   3.0s
# [CV 3/10; 9/20] START clf__C=0.06951927961775606................................
# [CV 10/10; 8/20] END .clf__C=0.0545559478116852;, score=0.513 total time=   3.3s
# [CV 4/10; 9/20] START clf__C=0.06951927961775606................................
# [CV 2/10; 9/20] END .clf__C=0.06951927961775606;, score=0.522 total time=   3.6s
# [CV 5/10; 9/20] START clf__C=0.06951927961775606................................
# [CV 1/10; 9/20] END .clf__C=0.06951927961775606;, score=0.462 total time=   3.7s
# [CV 6/10; 9/20] START clf__C=0.06951927961775606................................
# [CV 3/10; 9/20] END .clf__C=0.06951927961775606;, score=0.438 total time=   3.8s
# [CV 7/10; 9/20] START clf__C=0.06951927961775606................................
# [CV 4/10; 9/20] END .clf__C=0.06951927961775606;, score=0.425 total time=   3.8s
# [CV 8/10; 9/20] START clf__C=0.06951927961775606................................
# [CV 5/10; 9/20] END .clf__C=0.06951927961775606;, score=0.438 total time=   3.6s
# [CV 9/10; 9/20] START clf__C=0.06951927961775606................................
# [CV 6/10; 9/20] END .clf__C=0.06951927961775606;, score=0.458 total time=   3.6s
# [CV 10/10; 9/20] START clf__C=0.06951927961775606...............................
# [CV 7/10; 9/20] END .clf__C=0.06951927961775606;, score=0.368 total time=   3.5s
# [CV 1/10; 10/20] START clf__C=0.08858667904100823...............................
# [CV 8/10; 9/20] END .clf__C=0.06951927961775606;, score=0.377 total time=   3.6s
# [CV 2/10; 10/20] START clf__C=0.08858667904100823...............................
# [CV 9/10; 9/20] END .clf__C=0.06951927961775606;, score=0.462 total time=   3.9s
# [CV 3/10; 10/20] START clf__C=0.08858667904100823...............................
# [CV 10/10; 9/20] END clf__C=0.06951927961775606;, score=0.513 total time=   3.8s
# [CV 4/10; 10/20] START clf__C=0.08858667904100823...............................
# [CV 1/10; 10/20] END clf__C=0.08858667904100823;, score=0.458 total time=   4.0s
# [CV 5/10; 10/20] START clf__C=0.08858667904100823...............................
# [CV 2/10; 10/20] END clf__C=0.08858667904100823;, score=0.507 total time=   3.8s
# [CV 6/10; 10/20] START clf__C=0.08858667904100823...............................
# [CV 4/10; 10/20] END clf__C=0.08858667904100823;, score=0.420 total time=   3.6s
# [CV 7/10; 10/20] START clf__C=0.08858667904100823...............................
# [CV 3/10; 10/20] END clf__C=0.08858667904100823;, score=0.442 total time=   3.9s
# [CV 8/10; 10/20] START clf__C=0.08858667904100823...............................
# [CV 5/10; 10/20] END clf__C=0.08858667904100823;, score=0.443 total time=   3.9s
# [CV 9/10; 10/20] START clf__C=0.08858667904100823...............................
# [CV 6/10; 10/20] END clf__C=0.08858667904100823;, score=0.458 total time=   3.7s
# [CV 10/10; 10/20] START clf__C=0.08858667904100823..............................
# [CV 7/10; 10/20] END clf__C=0.08858667904100823;, score=0.370 total time=   3.9s
# [CV 1/10; 11/20] START clf__C=0.11288378916846889...............................
# [CV 8/10; 10/20] END clf__C=0.08858667904100823;, score=0.377 total time=   3.8s
# [CV 2/10; 11/20] START clf__C=0.11288378916846889...............................
# [CV 9/10; 10/20] END clf__C=0.08858667904100823;, score=0.463 total time=   4.1s
# [CV 3/10; 11/20] START clf__C=0.11288378916846889...............................
# [CV 10/10; 10/20] END clf__C=0.08858667904100823;, score=0.503 total time=   4.2s
# [CV 4/10; 11/20] START clf__C=0.11288378916846889...............................
# [CV 2/10; 11/20] END clf__C=0.11288378916846889;, score=0.500 total time=   4.2s
# [CV 5/10; 11/20] START clf__C=0.11288378916846889...............................
# [CV 1/10; 11/20] END clf__C=0.11288378916846889;, score=0.455 total time=   4.5s
# [CV 6/10; 11/20] START clf__C=0.11288378916846889...............................
# [CV 3/10; 11/20] END clf__C=0.11288378916846889;, score=0.442 total time=   4.2s
# [CV 7/10; 11/20] START clf__C=0.11288378916846889...............................
# [CV 4/10; 11/20] END clf__C=0.11288378916846889;, score=0.418 total time=   3.7s
# [CV 8/10; 11/20] START clf__C=0.11288378916846889...............................
# [CV 5/10; 11/20] END clf__C=0.11288378916846889;, score=0.447 total time=   4.0s
# [CV 9/10; 11/20] START clf__C=0.11288378916846889...............................
# [CV 6/10; 11/20] END clf__C=0.11288378916846889;, score=0.462 total time=   4.2s
# [CV 10/10; 11/20] START clf__C=0.11288378916846889..............................
# [CV 7/10; 11/20] END clf__C=0.11288378916846889;, score=0.373 total time=   4.2s
# [CV 1/10; 12/20] START clf__C=0.14384498882876628...............................
# [CV 8/10; 11/20] END clf__C=0.11288378916846889;, score=0.373 total time=   4.3s
# [CV 2/10; 12/20] START clf__C=0.14384498882876628...............................
# [CV 9/10; 11/20] END clf__C=0.11288378916846889;, score=0.467 total time=   4.2s
# [CV 10/10; 11/20] END clf__C=0.11288378916846889;, score=0.502 total time=   3.9s
# [CV 3/10; 12/20] START clf__C=0.14384498882876628...............................
# [CV 4/10; 12/20] START clf__C=0.14384498882876628...............................
# [CV 1/10; 12/20] END clf__C=0.14384498882876628;, score=0.460 total time=   4.5s
# [CV 5/10; 12/20] START clf__C=0.14384498882876628...............................
# [CV 2/10; 12/20] END clf__C=0.14384498882876628;, score=0.497 total time=   4.3s
# [CV 6/10; 12/20] START clf__C=0.14384498882876628...............................
# [CV 3/10; 12/20] END clf__C=0.14384498882876628;, score=0.443 total time=   4.4s
# [CV 7/10; 12/20] START clf__C=0.14384498882876628...............................
# [CV 4/10; 12/20] END clf__C=0.14384498882876628;, score=0.415 total time=   4.6s
# [CV 8/10; 12/20] START clf__C=0.14384498882876628...............................
# [CV 5/10; 12/20] END clf__C=0.14384498882876628;, score=0.452 total time=   4.2s
# [CV 9/10; 12/20] START clf__C=0.14384498882876628...............................
# [CV 6/10; 12/20] END clf__C=0.14384498882876628;, score=0.462 total time=   4.7s
# [CV 10/10; 12/20] START clf__C=0.14384498882876628..............................
# [CV 7/10; 12/20] END clf__C=0.14384498882876628;, score=0.373 total time=   4.4s
# [CV 1/10; 13/20] START clf__C=0.18329807108324356...............................
# [CV 8/10; 12/20] END clf__C=0.14384498882876628;, score=0.375 total time=   4.5s
# [CV 2/10; 13/20] START clf__C=0.18329807108324356...............................
# [CV 9/10; 12/20] END clf__C=0.14384498882876628;, score=0.468 total time=   4.5s
# [CV 3/10; 13/20] START clf__C=0.18329807108324356...............................
# [CV 10/10; 12/20] END clf__C=0.14384498882876628;, score=0.492 total time=   4.5s
# [CV 4/10; 13/20] START clf__C=0.18329807108324356...............................
# [CV 1/10; 13/20] END clf__C=0.18329807108324356;, score=0.460 total time=   4.9s
# [CV 5/10; 13/20] START clf__C=0.18329807108324356...............................
# [CV 2/10; 13/20] END clf__C=0.18329807108324356;, score=0.503 total time=   5.0s
# [CV 6/10; 13/20] START clf__C=0.18329807108324356...............................
# [CV 3/10; 13/20] END clf__C=0.18329807108324356;, score=0.448 total time=   5.0s
# [CV 7/10; 13/20] START clf__C=0.18329807108324356...............................
# [CV 4/10; 13/20] END clf__C=0.18329807108324356;, score=0.413 total time=   5.0s
# [CV 8/10; 13/20] START clf__C=0.18329807108324356...............................
# [CV 5/10; 13/20] END clf__C=0.18329807108324356;, score=0.453 total time=   4.9s
# [CV 9/10; 13/20] START clf__C=0.18329807108324356...............................
# [CV 6/10; 13/20] END clf__C=0.18329807108324356;, score=0.463 total time=   4.6s
# [CV 10/10; 13/20] START clf__C=0.18329807108324356..............................
# [CV 7/10; 13/20] END clf__C=0.18329807108324356;, score=0.372 total time=   4.6s
# [CV 1/10; 14/20] START clf__C=0.23357214690901212...............................
# [CV 8/10; 13/20] END clf__C=0.18329807108324356;, score=0.375 total time=   4.5s
# [CV 2/10; 14/20] START clf__C=0.23357214690901212...............................
# [CV 9/10; 13/20] END clf__C=0.18329807108324356;, score=0.463 total time=   4.9s
# [CV 3/10; 14/20] START clf__C=0.23357214690901212...............................
# [CV 10/10; 13/20] END clf__C=0.18329807108324356;, score=0.488 total time=   4.9s
# [CV 4/10; 14/20] START clf__C=0.23357214690901212...............................
# [CV 2/10; 14/20] END clf__C=0.23357214690901212;, score=0.497 total time=   5.0s
# [CV 5/10; 14/20] START clf__C=0.23357214690901212...............................
# [CV 1/10; 14/20] END clf__C=0.23357214690901212;, score=0.458 total time=   5.6s
# [CV 6/10; 14/20] START clf__C=0.23357214690901212...............................
# [CV 3/10; 14/20] END clf__C=0.23357214690901212;, score=0.447 total time=   5.2s
# [CV 7/10; 14/20] START clf__C=0.23357214690901212...............................
# [CV 4/10; 14/20] END clf__C=0.23357214690901212;, score=0.415 total time=   5.4s
# [CV 8/10; 14/20] START clf__C=0.23357214690901212...............................
# [CV 6/10; 14/20] END clf__C=0.23357214690901212;, score=0.465 total time=   4.9s
# [CV 9/10; 14/20] START clf__C=0.23357214690901212...............................
# [CV 5/10; 14/20] END clf__C=0.23357214690901212;, score=0.453 total time=   5.1s
# [CV 10/10; 14/20] START clf__C=0.23357214690901212..............................
# [CV 7/10; 14/20] END clf__C=0.23357214690901212;, score=0.375 total time=   5.1s
# [CV 1/10; 15/20] START clf__C=0.29763514416313175...............................
# [CV 8/10; 14/20] END clf__C=0.23357214690901212;, score=0.370 total time=   5.0s
# [CV 2/10; 15/20] START clf__C=0.29763514416313175...............................
# [CV 9/10; 14/20] END clf__C=0.23357214690901212;, score=0.455 total time=   5.0s
# [CV 3/10; 15/20] START clf__C=0.29763514416313175...............................
# [CV 10/10; 14/20] END clf__C=0.23357214690901212;, score=0.497 total time=   5.2s
# [CV 4/10; 15/20] START clf__C=0.29763514416313175...............................
# [CV 1/10; 15/20] END clf__C=0.29763514416313175;, score=0.452 total time=   5.3s
# [CV 5/10; 15/20] START clf__C=0.29763514416313175...............................
# [CV 2/10; 15/20] END clf__C=0.29763514416313175;, score=0.487 total time=   5.6s
# [CV 6/10; 15/20] START clf__C=0.29763514416313175...............................
# [CV 3/10; 15/20] END clf__C=0.29763514416313175;, score=0.447 total time=   5.5s
# [CV 7/10; 15/20] START clf__C=0.29763514416313175...............................
# [CV 4/10; 15/20] END clf__C=0.29763514416313175;, score=0.417 total time=   5.5s
# [CV 8/10; 15/20] START clf__C=0.29763514416313175...............................
# [CV 6/10; 15/20] END clf__C=0.29763514416313175;, score=0.462 total time=   5.2s
# [CV 9/10; 15/20] START clf__C=0.29763514416313175...............................
# [CV 5/10; 15/20] END clf__C=0.29763514416313175;, score=0.460 total time=   5.7s
# [CV 10/10; 15/20] START clf__C=0.29763514416313175..............................
# [CV 8/10; 15/20] END clf__C=0.29763514416313175;, score=0.378 total time=   5.3s
# [CV 1/10; 16/20] START clf__C=0.37926901907322497...............................
# [CV 7/10; 15/20] END clf__C=0.29763514416313175;, score=0.372 total time=   5.5s
# [CV 2/10; 16/20] START clf__C=0.37926901907322497...............................
# [CV 10/10; 15/20] END clf__C=0.29763514416313175;, score=0.497 total time=   5.3s
# [CV 3/10; 16/20] START clf__C=0.37926901907322497...............................
# [CV 9/10; 15/20] END clf__C=0.29763514416313175;, score=0.455 total time=   5.7s
# [CV 4/10; 16/20] START clf__C=0.37926901907322497...............................
# [CV 2/10; 16/20] END clf__C=0.37926901907322497;, score=0.483 total time=   5.8s
# [CV 5/10; 16/20] START clf__C=0.37926901907322497...............................
# [CV 1/10; 16/20] END clf__C=0.37926901907322497;, score=0.453 total time=   6.6s
# [CV 6/10; 16/20] START clf__C=0.37926901907322497...............................
# [CV 3/10; 16/20] END clf__C=0.37926901907322497;, score=0.448 total time=   6.1s
# [CV 7/10; 16/20] START clf__C=0.37926901907322497...............................
# [CV 4/10; 16/20] END clf__C=0.37926901907322497;, score=0.412 total time=   6.0s
# [CV 8/10; 16/20] START clf__C=0.37926901907322497...............................
# [CV 5/10; 16/20] END clf__C=0.37926901907322497;, score=0.457 total time=   5.7s
# [CV 9/10; 16/20] START clf__C=0.37926901907322497...............................
# [CV 6/10; 16/20] END clf__C=0.37926901907322497;, score=0.465 total time=   5.7s
# [CV 10/10; 16/20] START clf__C=0.37926901907322497..............................
# [CV 8/10; 16/20] END clf__C=0.37926901907322497;, score=0.378 total time=   5.1s
# [CV 1/10; 17/20] START clf__C=0.4832930238571752................................
# [CV 7/10; 16/20] END clf__C=0.37926901907322497;, score=0.357 total time=   5.9s
# [CV 2/10; 17/20] START clf__C=0.4832930238571752................................
# [CV 9/10; 16/20] END clf__C=0.37926901907322497;, score=0.453 total time=   5.8s
# [CV 3/10; 17/20] START clf__C=0.4832930238571752................................
# [CV 10/10; 16/20] END clf__C=0.37926901907322497;, score=0.492 total time=   6.4s
# [CV 4/10; 17/20] START clf__C=0.4832930238571752................................
# [CV 1/10; 17/20] END .clf__C=0.4832930238571752;, score=0.452 total time=   6.9s
# [CV 2/10; 17/20] END .clf__C=0.4832930238571752;, score=0.482 total time=   6.3s
# [CV 5/10; 17/20] START clf__C=0.4832930238571752................................
# [CV 6/10; 17/20] START clf__C=0.4832930238571752................................
# [CV 3/10; 17/20] END .clf__C=0.4832930238571752;, score=0.440 total time=   6.6s
# [CV 7/10; 17/20] START clf__C=0.4832930238571752................................
# [CV 4/10; 17/20] END .clf__C=0.4832930238571752;, score=0.407 total time=   6.2s
# [CV 8/10; 17/20] START clf__C=0.4832930238571752................................
# [CV 5/10; 17/20] END .clf__C=0.4832930238571752;, score=0.458 total time=   6.1s
# [CV 9/10; 17/20] START clf__C=0.4832930238571752................................
# [CV 6/10; 17/20] END .clf__C=0.4832930238571752;, score=0.472 total time=   6.5s
# [CV 10/10; 17/20] START clf__C=0.4832930238571752...............................
# [CV 7/10; 17/20] END .clf__C=0.4832930238571752;, score=0.357 total time=   5.9s
# [CV 1/10; 18/20] START clf__C=0.615848211066026.................................
# [CV 8/10; 17/20] END .clf__C=0.4832930238571752;, score=0.382 total time=   5.5s
# [CV 2/10; 18/20] START clf__C=0.615848211066026.................................
# [CV 9/10; 17/20] END .clf__C=0.4832930238571752;, score=0.452 total time=   6.7s
# [CV 3/10; 18/20] START clf__C=0.615848211066026.................................
# [CV 10/10; 17/20] END clf__C=0.4832930238571752;, score=0.488 total time=   6.3s
# [CV 4/10; 18/20] START clf__C=0.615848211066026.................................
# [CV 1/10; 18/20] END ..clf__C=0.615848211066026;, score=0.455 total time=   7.6s
# [CV 5/10; 18/20] START clf__C=0.615848211066026.................................
# [CV 2/10; 18/20] END ..clf__C=0.615848211066026;, score=0.470 total time=   7.6s
# [CV 6/10; 18/20] START clf__C=0.615848211066026.................................
# [CV 3/10; 18/20] END ..clf__C=0.615848211066026;, score=0.435 total time=   6.9s
# [CV 7/10; 18/20] START clf__C=0.615848211066026.................................
# [CV 4/10; 18/20] END ..clf__C=0.615848211066026;, score=0.403 total time=   7.1s
# [CV 8/10; 18/20] START clf__C=0.615848211066026.................................
# [CV 5/10; 18/20] END ..clf__C=0.615848211066026;, score=0.452 total time=   6.9s
# [CV 9/10; 18/20] START clf__C=0.615848211066026.................................
# [CV 6/10; 18/20] END ..clf__C=0.615848211066026;, score=0.475 total time=   7.3s
# [CV 10/10; 18/20] START clf__C=0.615848211066026................................
# [CV 7/10; 18/20] END ..clf__C=0.615848211066026;, score=0.357 total time=   6.5s
# [CV 1/10; 19/20] START clf__C=0.7847599703514611................................
# [CV 8/10; 18/20] END ..clf__C=0.615848211066026;, score=0.380 total time=   6.4s
# [CV 2/10; 19/20] START clf__C=0.7847599703514611................................
# [CV 9/10; 18/20] END ..clf__C=0.615848211066026;, score=0.453 total time=   6.9s
# [CV 3/10; 19/20] START clf__C=0.7847599703514611................................
# [CV 10/10; 18/20] END .clf__C=0.615848211066026;, score=0.480 total time=   6.8s
# [CV 4/10; 19/20] START clf__C=0.7847599703514611................................
# [CV 1/10; 19/20] END .clf__C=0.7847599703514611;, score=0.452 total time=   7.1s
# [CV 5/10; 19/20] START clf__C=0.7847599703514611................................
# [CV 2/10; 19/20] END .clf__C=0.7847599703514611;, score=0.468 total time=   7.5s
# [CV 6/10; 19/20] START clf__C=0.7847599703514611................................
# [CV 3/10; 19/20] END .clf__C=0.7847599703514611;, score=0.435 total time=   7.3s
# [CV 7/10; 19/20] START clf__C=0.7847599703514611................................
# [CV 4/10; 19/20] END .clf__C=0.7847599703514611;, score=0.403 total time=   7.3s
# [CV 8/10; 19/20] START clf__C=0.7847599703514611................................
# [CV 5/10; 19/20] END .clf__C=0.7847599703514611;, score=0.448 total time=   7.5s
# [CV 9/10; 19/20] START clf__C=0.7847599703514611................................
# [CV 6/10; 19/20] END .clf__C=0.7847599703514611;, score=0.478 total time=   7.2s
# [CV 10/10; 19/20] START clf__C=0.7847599703514611...............................
# [CV 7/10; 19/20] END .clf__C=0.7847599703514611;, score=0.348 total time=   7.2s
# [CV 1/10; 20/20] START clf__C=1.0...............................................
# [CV 8/10; 19/20] END .clf__C=0.7847599703514611;, score=0.382 total time=   7.2s
# [CV 2/10; 20/20] START clf__C=1.0...............................................
# [CV 9/10; 19/20] END .clf__C=0.7847599703514611;, score=0.460 total time=   7.0s
# [CV 3/10; 20/20] START clf__C=1.0...............................................
# [CV 10/10; 19/20] END clf__C=0.7847599703514611;, score=0.487 total time=   7.7s
# [CV 4/10; 20/20] START clf__C=1.0...............................................
# [CV 1/10; 20/20] END ................clf__C=1.0;, score=0.448 total time=   7.9s
# [CV 5/10; 20/20] START clf__C=1.0...............................................
# [CV 2/10; 20/20] END ................clf__C=1.0;, score=0.465 total time=   7.9s
# [CV 6/10; 20/20] START clf__C=1.0...............................................
# [CV 3/10; 20/20] END ................clf__C=1.0;, score=0.440 total time=   8.1s
# [CV 7/10; 20/20] START clf__C=1.0...............................................
# [CV 4/10; 20/20] END ................clf__C=1.0;, score=0.398 total time=   7.4s
# [CV 8/10; 20/20] START clf__C=1.0...............................................
# [CV 5/10; 20/20] END ................clf__C=1.0;, score=0.450 total time=   7.7s
# [CV 9/10; 20/20] START clf__C=1.0...............................................
# [CV 6/10; 20/20] END ................clf__C=1.0;, score=0.478 total time=   7.7s
# [CV 10/10; 20/20] START clf__C=1.0..............................................
# [CV 8/10; 20/20] END ................clf__C=1.0;, score=0.377 total time=   7.3s
# [CV 7/10; 20/20] END ................clf__C=1.0;, score=0.352 total time=   8.2s
# [CV 9/10; 20/20] END ................clf__C=1.0;, score=0.458 total time=   7.4s
# [CV 10/10; 20/20] END ...............clf__C=1.0;, score=0.493 total time=   7.3s
# Best Parameters: {'clf__C': 0.0545559478116852}
# Best Mean Accuracy: 0.45000000000000007

# %%
pipeline = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('clf', LogisticRegression(max_iter=9999))
])

param_grid = {
    'vectorizer__max_features': [5000, 6000, None],
    'clf__C': [0.01, 0.1, 1.0, 10.0, 100.0],
    'clf__penalty': ['l1', 'l2'],
    'clf__solver': ['lbfgs', 'liblinear', 'saga']
}

grid_search = GridSearchCV(pipeline, param_grid, cv=10, scoring='accuracy', n_jobs=4, verbose=10)

grid_search.fit(X, Y)

best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

# Calculate the mean accuracy using cross-validation
mean_accuracy = cross_val_score(best_estimator, X, Y, scoring='accuracy', cv=10).mean()

print("Best Parameters:", best_params)
print("Best Mean Accuracy:", mean_accuracy)
# Out:
# Fitting 10 folds for each of 180 candidates, totalling 1800 fits
# [CV 2/10; 1/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 3/10; 1/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 1/10; 1/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 4/10; 1/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 2/10; 1/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500;, score=nan total time=   0.3s
# [CV 3/10; 1/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500;, score=nan total time=   0.3s
# [CV 4/10; 1/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500;, score=nan total time=   0.3s
# [CV 1/10; 1/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500;, score=nan total time=   0.3s
# [CV 5/10; 1/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 6/10; 1/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 7/10; 1/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 8/10; 1/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 6/10; 1/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500;, score=nan total time=   0.3s
# [CV 5/10; 1/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500;, score=nan total time=   0.3s
# [CV 7/10; 1/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500;, score=nan total time=   0.3s
# [CV 9/10; 1/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 8/10; 1/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500;, score=nan total time=   0.3s
# [CV 10/10; 1/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 1/10; 2/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 2/10; 2/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 9/10; 1/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500;, score=nan total time=   0.3s
# [CV 10/10; 1/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=500;, score=nan total time=   0.3s
# [CV 3/10; 2/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 4/10; 2/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 1/10; 2/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000;, score=nan total time=   0.3s
# [CV 2/10; 2/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000;, score=nan total time=   0.3s
# [CV 5/10; 2/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 6/10; 2/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 3/10; 2/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000;, score=nan total time=   0.3s
# [CV 4/10; 2/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000;, score=nan total time=   0.3s
# [CV 7/10; 2/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 8/10; 2/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 5/10; 2/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000;, score=nan total time=   0.3s
# [CV 6/10; 2/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000;, score=nan total time=   0.3s
# [CV 9/10; 2/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 10/10; 2/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 7/10; 2/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000;, score=nan total time=   0.3s
# [CV 8/10; 2/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000;, score=nan total time=   0.3s
# [CV 1/10; 3/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 9/10; 2/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000;, score=nan total time=   0.3s
# [CV 2/10; 3/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 10/10; 2/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=1000;, score=nan total time=   0.3s
# [CV 3/10; 3/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 4/10; 3/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 1/10; 3/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000;, score=nan total time=   0.3s
# [CV 5/10; 3/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 2/10; 3/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000;, score=nan total time=   0.3s
# [CV 6/10; 3/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 3/10; 3/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000;, score=nan total time=   0.3s
# [CV 7/10; 3/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 4/10; 3/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000;, score=nan total time=   0.3s
# [CV 8/10; 3/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 5/10; 3/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000;, score=nan total time=   0.3s
# [CV 6/10; 3/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000;, score=nan total time=   0.3s
# [CV 9/10; 3/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 10/10; 3/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 7/10; 3/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000;, score=nan total time=   0.3s
# [CV 1/10; 4/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 8/10; 3/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000;, score=nan total time=   0.3s
# [CV 2/10; 4/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 9/10; 3/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000;, score=nan total time=   0.3s
# [CV 10/10; 3/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=4000;, score=nan total time=   0.3s
# [CV 3/10; 4/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 4/10; 4/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 1/10; 4/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 5/10; 4/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 2/10; 4/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 6/10; 4/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 4/10; 4/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 3/10; 4/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 7/10; 4/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 8/10; 4/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 5/10; 4/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 9/10; 4/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 6/10; 4/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 10/10; 4/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 7/10; 4/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 8/10; 4/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 1/10; 5/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000
# [CV 2/10; 5/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000
# [CV 9/10; 4/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 3/10; 5/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000
# [CV 10/10; 4/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 4/10; 5/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000
# [CV 1/10; 5/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000;, score=nan total time=   0.3s
# [CV 2/10; 5/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000;, score=nan total time=   0.3s
# [CV 5/10; 5/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000
# [CV 6/10; 5/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000
# [CV 3/10; 5/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000;, score=nan total time=   0.3s
# [CV 7/10; 5/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000
# [CV 4/10; 5/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000;, score=nan total time=   0.3s
# [CV 8/10; 5/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000
# [CV 5/10; 5/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000;, score=nan total time=   0.3s
# [CV 6/10; 5/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000;, score=nan total time=   0.3s
# [CV 9/10; 5/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000
# [CV 10/10; 5/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000
# [CV 7/10; 5/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000;, score=nan total time=   0.3s
# [CV 1/10; 6/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 8/10; 5/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000;, score=nan total time=   0.3s
# [CV 2/10; 6/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 9/10; 5/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000;, score=nan total time=   0.3s
# [CV 3/10; 6/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 10/10; 5/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=6000;, score=nan total time=   0.3s
# [CV 4/10; 6/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 1/10; 6/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 5/10; 6/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 2/10; 6/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 6/10; 6/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 3/10; 6/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 4/10; 6/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 7/10; 6/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 8/10; 6/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 5/10; 6/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 9/10; 6/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 6/10; 6/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 10/10; 6/180] START clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 7/10; 6/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 1/10; 7/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500
# [CV 8/10; 6/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 2/10; 7/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500
# [CV 9/10; 6/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 3/10; 7/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500
# [CV 10/10; 6/180] END clf__C=0.01, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 4/10; 7/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500
# [CV 1/10; 7/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500;, score=0.453 total time=   0.3s
# [CV 5/10; 7/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500
# [CV 2/10; 7/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500;, score=0.462 total time=   0.4s
# [CV 6/10; 7/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500
# [CV 3/10; 7/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500;, score=0.395 total time=   0.4s
# [CV 7/10; 7/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500
# [CV 4/10; 7/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500;, score=0.428 total time=   0.4s
# [CV 8/10; 7/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500
# [CV 5/10; 7/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500;, score=0.405 total time=   0.4s
# [CV 9/10; 7/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500
# [CV 6/10; 7/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500;, score=0.463 total time=   0.4s
# [CV 10/10; 7/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500
# [CV 7/10; 7/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500;, score=0.343 total time=   0.4s
# [CV 1/10; 8/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000
# [CV 8/10; 7/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500;, score=0.428 total time=   0.4s
# [CV 2/10; 8/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000
# [CV 9/10; 7/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500;, score=0.423 total time=   0.3s
# [CV 3/10; 8/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000
# [CV 10/10; 7/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=500;, score=0.412 total time=   0.4s
# [CV 4/10; 8/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000
# [CV 1/10; 8/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000;, score=0.453 total time=   0.4s
# [CV 5/10; 8/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000
# [CV 2/10; 8/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000;, score=0.460 total time=   0.4s
# [CV 6/10; 8/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000
# [CV 3/10; 8/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000;, score=0.395 total time=   0.4s
# [CV 7/10; 8/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000
# [CV 4/10; 8/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000;, score=0.428 total time=   0.4s
# [CV 8/10; 8/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000
# [CV 5/10; 8/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000;, score=0.405 total time=   0.4s
# [CV 9/10; 8/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000
# [CV 6/10; 8/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000;, score=0.463 total time=   0.4s
# [CV 10/10; 8/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000
# [CV 7/10; 8/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000;, score=0.343 total time=   0.4s
# [CV 1/10; 9/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000
# [CV 8/10; 8/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000;, score=0.428 total time=   0.4s
# [CV 2/10; 9/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000
# [CV 9/10; 8/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000;, score=0.423 total time=   0.4s
# [CV 3/10; 9/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000
# [CV 10/10; 8/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=1000;, score=0.412 total time=   0.4s
# [CV 4/10; 9/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000
# [CV 1/10; 9/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000;, score=0.453 total time=   0.4s
# [CV 5/10; 9/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000
# [CV 2/10; 9/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000;, score=0.458 total time=   0.4s
# [CV 6/10; 9/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000
# [CV 3/10; 9/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000;, score=0.395 total time=   0.4s
# [CV 7/10; 9/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000
# [CV 4/10; 9/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000;, score=0.428 total time=   0.4s
# [CV 8/10; 9/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000
# [CV 5/10; 9/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000;, score=0.405 total time=   0.4s
# [CV 9/10; 9/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000
# [CV 6/10; 9/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000;, score=0.463 total time=   0.4s
# [CV 10/10; 9/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000
# [CV 7/10; 9/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000;, score=0.343 total time=   0.4s
# [CV 1/10; 10/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 8/10; 9/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000;, score=0.428 total time=   0.4s
# [CV 2/10; 10/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 9/10; 9/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000;, score=0.423 total time=   0.4s
# [CV 3/10; 10/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 10/10; 9/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=4000;, score=0.412 total time=   0.4s
# [CV 4/10; 10/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 1/10; 10/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.453 total time=   0.4s
# [CV 5/10; 10/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 2/10; 10/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.460 total time=   0.4s
# [CV 6/10; 10/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 3/10; 10/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.395 total time=   0.4s
# [CV 7/10; 10/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 4/10; 10/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.428 total time=   0.4s
# [CV 8/10; 10/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 5/10; 10/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.405 total time=   0.4s
# [CV 9/10; 10/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 6/10; 10/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.463 total time=   0.4s
# [CV 10/10; 10/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 7/10; 10/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.343 total time=   0.4s
# [CV 1/10; 11/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 8/10; 10/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.428 total time=   0.4s
# [CV 2/10; 11/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 9/10; 10/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.425 total time=   0.4s
# [CV 3/10; 11/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 10/10; 10/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.412 total time=   0.4s
# [CV 4/10; 11/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 1/10; 11/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.453 total time=   0.4s
# [CV 5/10; 11/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 2/10; 11/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.460 total time=   0.4s
# [CV 6/10; 11/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 3/10; 11/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.395 total time=   0.4s
# [CV 7/10; 11/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 4/10; 11/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.428 total time=   0.4s
# [CV 8/10; 11/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 5/10; 11/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.405 total time=   0.4s
# [CV 9/10; 11/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 6/10; 11/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.463 total time=   0.4s
# [CV 10/10; 11/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 7/10; 11/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.343 total time=   0.4s
# [CV 1/10; 12/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 8/10; 11/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.428 total time=   0.4s
# [CV 2/10; 12/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 9/10; 11/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.425 total time=   0.4s
# [CV 3/10; 12/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 10/10; 11/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.412 total time=   0.4s
# [CV 4/10; 12/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 1/10; 12/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.453 total time=   0.4s
# [CV 5/10; 12/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 2/10; 12/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.460 total time=   0.4s
# [CV 6/10; 12/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 3/10; 12/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.395 total time=   0.4s
# [CV 7/10; 12/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 4/10; 12/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.428 total time=   0.4s
# [CV 8/10; 12/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 5/10; 12/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.405 total time=   0.4s
# [CV 9/10; 12/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 6/10; 12/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.463 total time=   0.4s
# [CV 10/10; 12/180] START clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 7/10; 12/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.343 total time=   0.4s
# [CV 8/10; 12/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.428 total time=   0.4s
# [CV 1/10; 13/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 2/10; 13/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 9/10; 12/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.423 total time=   0.4s
# [CV 3/10; 13/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 10/10; 12/180] END clf__C=0.01, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.412 total time=   0.4s
# [CV 4/10; 13/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 3/10; 13/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.397 total time=  10.1s
# [CV 5/10; 13/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 1/10; 13/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.465 total time=  14.4s
# [CV 6/10; 13/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 4/10; 13/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.413 total time=  17.2s
# [CV 7/10; 13/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 5/10; 13/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.395 total time=  10.8s
# [CV 8/10; 13/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 2/10; 13/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.483 total time=  22.3s
# [CV 9/10; 13/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 6/10; 13/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.460 total time=  11.4s
# [CV 10/10; 13/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 7/10; 13/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.358 total time=  15.7s
# [CV 1/10; 14/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 9/10; 13/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.360 total time=  14.8s
# [CV 2/10; 14/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 10/10; 13/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.417 total time=  12.7s
# [CV 3/10; 14/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 8/10; 13/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.373 total time=  17.6s
# [CV 4/10; 14/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 1/10; 14/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.465 total time=  16.7s
# [CV 5/10; 14/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 3/10; 14/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.397 total time=  11.4s
# [CV 6/10; 14/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 4/10; 14/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.413 total time=  20.2s
# [CV 7/10; 14/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 2/10; 14/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.485 total time=  22.9s
# [CV 8/10; 14/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 5/10; 14/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.397 total time=  12.6s
# [CV 9/10; 14/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 6/10; 14/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.458 total time=  13.3s
# [CV 10/10; 14/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 8/10; 14/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.383 total time=   8.8s
# [CV 1/10; 15/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 7/10; 14/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.360 total time=  17.9s
# [CV 2/10; 15/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 10/10; 14/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.417 total time=  15.4s
# [CV 3/10; 15/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 9/10; 14/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.362 total time=  17.6s
# [CV 4/10; 15/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 1/10; 15/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.465 total time=  21.3s
# [CV 5/10; 15/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 3/10; 15/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.393 total time=  14.5s
# [CV 6/10; 15/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 2/10; 15/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.485 total time=  29.0s
# [CV 7/10; 15/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 4/10; 15/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.413 total time=  26.0s
# [CV 8/10; 15/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 5/10; 15/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.397 total time=  15.8s
# [CV 9/10; 15/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 6/10; 15/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.458 total time=  16.6s
# [CV 10/10; 15/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 8/10; 15/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.383 total time=  11.3s
# [CV 1/10; 16/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 9/10; 15/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.362 total time=  21.8s
# [CV 2/10; 16/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 7/10; 15/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.360 total time=  22.5s
# [CV 3/10; 16/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 10/10; 15/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.417 total time=  18.7s
# [CV 4/10; 16/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 1/10; 16/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.463 total time=  21.2s
# [CV 5/10; 16/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 3/10; 16/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.393 total time=  14.4s
# [CV 6/10; 16/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 4/10; 16/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.413 total time=  25.9s
# [CV 7/10; 16/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 5/10; 16/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.395 total time=  15.8s
# [CV 8/10; 16/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 2/10; 16/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.485 total time=  29.0s
# [CV 9/10; 16/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 6/10; 16/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.458 total time=  16.7s
# [CV 10/10; 16/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 8/10; 16/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.383 total time=  11.5s
# [CV 1/10; 17/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000
# [CV 7/10; 16/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.360 total time=  23.5s
# [CV 2/10; 17/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000
# [CV 10/10; 16/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.417 total time=  19.6s
# [CV 3/10; 17/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000
# [CV 9/10; 16/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.362 total time=  22.8s
# [CV 4/10; 17/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000
# [CV 1/10; 17/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000;, score=0.463 total time=  22.5s
# [CV 5/10; 17/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000
# [CV 3/10; 17/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000;, score=0.393 total time=  15.2s
# [CV 6/10; 17/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000
# [CV 5/10; 17/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000;, score=0.393 total time=  16.6s
# [CV 7/10; 17/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000
# [CV 4/10; 17/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000;, score=0.413 total time=  27.4s
# [CV 8/10; 17/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000
# [CV 2/10; 17/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000;, score=0.485 total time=  30.7s
# [CV 9/10; 17/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000
# [CV 6/10; 17/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000;, score=0.458 total time=  17.7s
# [CV 10/10; 17/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000
# [CV 8/10; 17/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000;, score=0.383 total time=  11.9s
# [CV 1/10; 18/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 7/10; 17/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000;, score=0.360 total time=  24.0s
# [CV 2/10; 18/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 9/10; 17/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000;, score=0.362 total time=  23.2s
# [CV 3/10; 18/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 10/10; 17/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=6000;, score=0.417 total time=  20.0s
# [CV 4/10; 18/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 1/10; 18/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.463 total time=  25.7s
# [CV 5/10; 18/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 3/10; 18/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.393 total time=  18.0s
# [CV 6/10; 18/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 4/10; 18/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.413 total time=  32.4s
# [CV 7/10; 18/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 5/10; 18/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.393 total time=  19.9s
# [CV 8/10; 18/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 2/10; 18/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.487 total time=  36.1s
# [CV 9/10; 18/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 6/10; 18/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.458 total time=  20.6s
# [CV 10/10; 18/180] START clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 8/10; 18/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.383 total time=  14.0s
# [CV 1/10; 19/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 1/10; 19/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500;, score=0.450 total time=   0.7s
# [CV 2/10; 19/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 2/10; 19/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500;, score=0.492 total time=   0.6s
# [CV 3/10; 19/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 3/10; 19/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500;, score=0.432 total time=   0.6s
# [CV 4/10; 19/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 4/10; 19/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500;, score=0.445 total time=   0.7s
# [CV 5/10; 19/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 5/10; 19/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500;, score=0.398 total time=   0.7s
# [CV 6/10; 19/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 6/10; 19/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500;, score=0.427 total time=   0.6s
# [CV 7/10; 19/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 7/10; 19/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500;, score=0.320 total time=   0.6s
# [CV 8/10; 19/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 8/10; 19/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500;, score=0.392 total time=   0.7s
# [CV 9/10; 19/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 9/10; 19/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500;, score=0.462 total time=   0.7s
# [CV 10/10; 19/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500
# [CV 10/10; 19/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=500;, score=0.462 total time=   0.7s
# [CV 1/10; 20/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 1/10; 20/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000;, score=0.468 total time=   0.8s
# [CV 2/10; 20/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 2/10; 20/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000;, score=0.492 total time=   0.7s
# [CV 3/10; 20/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 3/10; 20/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000;, score=0.428 total time=   0.7s
# [CV 4/10; 20/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 4/10; 20/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000;, score=0.437 total time=   0.7s
# [CV 5/10; 20/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 5/10; 20/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000;, score=0.433 total time=   0.8s
# [CV 6/10; 20/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 6/10; 20/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000;, score=0.435 total time=   0.8s
# [CV 7/10; 20/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 7/10; 20/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000;, score=0.367 total time=   0.7s
# [CV 8/10; 20/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 8/10; 20/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000;, score=0.367 total time=   0.7s
# [CV 9/10; 20/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 7/10; 18/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.360 total time=  27.5s
# [CV 10/10; 20/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000
# [CV 9/10; 18/180] END clf__C=0.01, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.362 total time=  26.6s
# [CV 1/10; 21/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 9/10; 20/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000;, score=0.477 total time=   0.8s
# [CV 2/10; 21/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 10/10; 20/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=1000;, score=0.473 total time=   0.8s
# [CV 3/10; 21/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=4000
# [CV 1/10; 21/180] END clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=4000;, score=0.448 total time=   1.1s
# [CV 4/10; 21/180] START clf__C=0.01, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=4000
# ...
# [CV 8/10; 83/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 6/10; 83/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.453 total time=   0.7s
# [CV 9/10; 83/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 5/10; 83/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.435 total time=   0.8s
# [CV 10/10; 83/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000
# [CV 7/10; 83/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.397 total time=   0.8s
# [CV 1/10; 84/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 8/10; 83/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.378 total time=   0.8s
# [CV 2/10; 84/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 9/10; 83/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.422 total time=   0.9s
# [CV 3/10; 84/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 10/10; 83/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=6000;, score=0.490 total time=   0.8s
# [CV 4/10; 84/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 1/10; 84/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.448 total time=   0.9s
# [CV 5/10; 84/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 2/10; 84/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.482 total time=   0.9s
# [CV 6/10; 84/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 3/10; 84/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.440 total time=   0.9s
# [CV 7/10; 84/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 4/10; 84/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.413 total time=   0.9s
# [CV 8/10; 84/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 6/10; 84/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.452 total time=   0.8s
# [CV 9/10; 84/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 5/10; 84/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.443 total time=   0.9s
# [CV 10/10; 84/180] START clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 7/10; 84/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.397 total time=   0.8s
# [CV 1/10; 85/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 8/10; 84/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.367 total time=   0.8s
# [CV 2/10; 85/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 9/10; 84/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.412 total time=   0.9s
# [CV 3/10; 85/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 10/10; 84/180] END clf__C=1.0, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.477 total time=   0.8s
# [CV 4/10; 85/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 2/10; 85/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.468 total time=  38.1s
# [CV 5/10; 85/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 3/10; 85/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.390 total time=  46.2s
# [CV 6/10; 85/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 4/10; 85/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.397 total time=  47.0s
# [CV 7/10; 85/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 1/10; 85/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.448 total time=  59.9s
# [CV 8/10; 85/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 6/10; 85/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.428 total time=  45.1s
# [CV 9/10; 85/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 7/10; 85/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.352 total time=  53.0s
# [CV 10/10; 85/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500
# [CV 5/10; 85/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.370 total time= 1.2min
# [CV 1/10; 86/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 8/10; 85/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.357 total time=  54.4s
# [CV 2/10; 86/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 9/10; 85/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.462 total time=  43.5s
# [CV 3/10; 86/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 10/10; 85/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=500;, score=0.497 total time=  52.8s
# [CV 4/10; 86/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 2/10; 86/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.470 total time= 1.7min
# [CV 5/10; 86/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 1/10; 86/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.452 total time= 2.1min
# [CV 6/10; 86/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 3/10; 86/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.412 total time= 2.6min
# [CV 7/10; 86/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 4/10; 86/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.400 total time= 2.4min
# [CV 8/10; 86/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 5/10; 86/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.440 total time= 2.3min
# [CV 9/10; 86/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 6/10; 86/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.433 total time= 2.6min
# [CV 10/10; 86/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000
# [CV 7/10; 86/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.393 total time= 2.4min
# [CV 1/10; 87/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 8/10; 86/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.338 total time= 2.5min
# [CV 2/10; 87/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 9/10; 86/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.398 total time= 2.5min
# [CV 3/10; 87/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 10/10; 86/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=1000;, score=0.482 total time= 2.2min
# [CV 4/10; 87/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 2/10; 87/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.477 total time= 6.7min
# [CV 5/10; 87/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 1/10; 87/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.445 total time= 7.3min
# [CV 6/10; 87/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 4/10; 87/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.407 total time= 6.7min
# [CV 7/10; 87/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# [CV 3/10; 87/180] END clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000;, score=0.432 total time= 7.4min
# [CV 8/10; 87/180] START clf__C=1.0, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=4000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/luizabm/Documents/GitHub/PLN/src/training/EP copy.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell:/Users/luizabm/Documents/GitHub/PLN/src/training/EP%20copy.ipynb#X50sZmlsZQ%3D%3D?line=8'>9</a> param_grid = {
#      <a href='vscode-notebook-cell:/Users/luizabm/Documents/GitHub/PLN/src/training/EP%20copy.ipynb#X50sZmlsZQ%3D%3D?line=9'>10</a>     'vectorizer__max_features': [500, 1000, 4000, 5000, 6000, None],
#      <a href='vscode-notebook-cell:/Users/luizabm/Documents/GitHub/PLN/src/training/EP%20copy.ipynb#X50sZmlsZQ%3D%3D?line=10'>11</a>     'clf__C': [0.01, 0.1, 1.0, 10.0, 100.0],
#      <a href='vscode-notebook-cell:/Users/luizabm/Documents/GitHub/PLN/src/training/EP%20copy.ipynb#X50sZmlsZQ%3D%3D?line=11'>12</a>     'clf__penalty': ['l1', 'l2'],
#      <a href='vscode-notebook-cell:/Users/luizabm/Documents/GitHub/PLN/src/training/EP%20copy.ipynb#X50sZmlsZQ%3D%3D?line=12'>13</a>     'clf__solver': ['lbfgs', 'liblinear', 'saga']
#      <a href='vscode-notebook-cell:/Users/luizabm/Documents/GitHub/PLN/src/training/EP%20copy.ipynb#X50sZmlsZQ%3D%3D?line=13'>14</a> }
#      <a href='vscode-notebook-cell:/Users/luizabm/Documents/GitHub/PLN/src/training/EP%20copy.ipynb#X50sZmlsZQ%3D%3D?line=15'>16</a> grid_search = GridSearchCV(pipeline, param_grid, cv=10, scoring='accuracy', n_jobs=4, verbose=10)
# ---> <a href='vscode-notebook-cell:/Users/luizabm/Documents/GitHub/PLN/src/training/EP%20copy.ipynb#X50sZmlsZQ%3D%3D?line=17'>18</a> grid_search.fit(X, Y)
#      <a href='vscode-notebook-cell:/Users/luizabm/Documents/GitHub/PLN/src/training/EP%20copy.ipynb#X50sZmlsZQ%3D%3D?line=19'>20</a> best_params = grid_search.best_params_
#      <a href='vscode-notebook-cell:/Users/luizabm/Documents/GitHub/PLN/src/training/EP%20copy.ipynb#X50sZmlsZQ%3D%3D?line=20'>21</a> best_estimator = grid_search.best_estimator_
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File /opt/homebrew/lib/python3.11/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File /opt/homebrew/lib/python3.11/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File /opt/homebrew/lib/python3.11/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
pipeline = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('clf', LogisticRegression(max_iter=9999))
])

param_grid = {
    'vectorizer__max_features': [5000, None],
    'vectorizer__lowercase': [True, False],
    'clf__C': [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1.0],
    'clf__class_weight': ['balanced', None],
    'clf__penalty': ['l1', 'l2'],
    'clf__solver': ['lbfgs', 'liblinear', 'saga']
}

grid_search = GridSearchCV(pipeline, param_grid, cv=10, scoring='accuracy', n_jobs=1, verbose=10)

grid_search.fit(X, Y)

best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

# Calculate the mean accuracy using cross-validation
mean_accuracy = cross_val_score(best_estimator, X, Y, scoring='accuracy', cv=10).mean()

print("Best Parameters:", best_params)
print("Best Mean Accuracy:", mean_accuracy)
# Out:
# Fitting 10 folds for each of 60 candidates, totalling 600 fits
# [CV 1/10; 1/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 2/10; 1/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 2/10; 1/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 1/10; 1/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 3/10; 1/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 4/10; 1/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 4/10; 1/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 3/10; 1/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 5/10; 1/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 6/10; 1/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 5/10; 1/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 6/10; 1/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 7/10; 1/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 8/10; 1/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 8/10; 1/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 7/10; 1/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 9/10; 1/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 10/10; 1/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 9/10; 1/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 10/10; 1/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 1/10; 2/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 2/10; 2/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 1/10; 2/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 2/10; 2/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 3/10; 2/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 4/10; 2/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 3/10; 2/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 4/10; 2/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 5/10; 2/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 6/10; 2/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 5/10; 2/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 6/10; 2/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 7/10; 2/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 8/10; 2/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 7/10; 2/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 8/10; 2/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 9/10; 2/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 10/10; 2/60] START clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 9/10; 2/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 10/10; 2/60] END clf__C=0.001, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 1/10; 3/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 2/10; 3/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 1/10; 3/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.348 total time=   0.3s
# [CV 2/10; 3/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.327 total time=   0.3s
# [CV 3/10; 3/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 4/10; 3/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 3/10; 3/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.327 total time=   0.3s
# [CV 5/10; 3/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 4/10; 3/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.335 total time=   0.3s
# [CV 6/10; 3/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 5/10; 3/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.322 total time=   0.3s
# [CV 7/10; 3/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 6/10; 3/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.352 total time=   0.3s
# [CV 8/10; 3/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 7/10; 3/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.330 total time=   0.4s
# [CV 9/10; 3/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 8/10; 3/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.322 total time=   0.4s
# [CV 10/10; 3/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 9/10; 3/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.337 total time=   0.3s
# [CV 1/10; 4/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 10/10; 3/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.323 total time=   0.3s
# [CV 2/10; 4/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 1/10; 4/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.348 total time=   0.4s
# [CV 3/10; 4/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 2/10; 4/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.327 total time=   0.4s
# [CV 4/10; 4/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 3/10; 4/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.327 total time=   0.4s
# [CV 5/10; 4/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 4/10; 4/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.335 total time=   0.4s
# [CV 6/10; 4/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 5/10; 4/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.322 total time=   0.3s
# [CV 7/10; 4/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 6/10; 4/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.352 total time=   0.4s
# [CV 8/10; 4/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 7/10; 4/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.330 total time=   0.3s
# [CV 9/10; 4/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 8/10; 4/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.322 total time=   0.4s
# [CV 10/10; 4/60] START clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 9/10; 4/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.337 total time=   0.3s
# [CV 1/10; 5/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 10/10; 4/60] END clf__C=0.001, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.323 total time=   0.3s
# [CV 2/10; 5/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 2/10; 5/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.445 total time=   9.8s
# [CV 3/10; 5/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 1/10; 5/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.363 total time=  10.4s
# [CV 4/10; 5/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 4/10; 5/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.418 total time=   6.2s
# [CV 5/10; 5/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 3/10; 5/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.373 total time=   9.6s
# [CV 6/10; 5/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 5/10; 5/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.335 total time=   9.2s
# [CV 7/10; 5/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 6/10; 5/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.398 total time=   9.9s
# [CV 8/10; 5/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 7/10; 5/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.368 total time=   8.2s
# [CV 9/10; 5/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 8/10; 5/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.445 total time=   8.1s
# [CV 10/10; 5/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 9/10; 5/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.387 total time=   9.5s
# [CV 1/10; 6/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 10/10; 5/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.338 total time=   9.8s
# [CV 2/10; 6/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 1/10; 6/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.368 total time=  10.9s
# [CV 3/10; 6/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 2/10; 6/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.443 total time=  10.7s
# [CV 4/10; 6/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 3/10; 6/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.375 total time=  13.0s
# [CV 5/10; 6/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 4/10; 6/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.433 total time=  11.3s
# [CV 6/10; 6/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 5/10; 6/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.335 total time=  11.4s
# [CV 7/10; 6/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 6/10; 6/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.398 total time=  11.5s
# [CV 8/10; 6/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 7/10; 6/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.368 total time=  11.1s
# [CV 9/10; 6/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 8/10; 6/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.445 total time=  10.9s
# [CV 10/10; 6/60] START clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 9/10; 6/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.387 total time=   9.5s
# [CV 1/10; 7/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 1/10; 7/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.450 total time=   0.7s
# [CV 2/10; 7/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 2/10; 7/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.505 total time=   0.7s
# [CV 3/10; 7/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 3/10; 7/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.417 total time=   0.7s
# [CV 4/10; 7/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 4/10; 7/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.448 total time=   0.7s
# [CV 5/10; 7/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 5/10; 7/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.440 total time=   0.6s
# [CV 6/10; 7/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 6/10; 7/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.443 total time=   0.6s
# [CV 7/10; 7/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 10/10; 6/60] END clf__C=0.001, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.343 total time=  12.3s
# [CV 8/10; 7/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 7/10; 7/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.337 total time=   0.6s
# [CV 9/10; 7/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 8/10; 7/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.433 total time=   0.7s
# [CV 10/10; 7/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 9/10; 7/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.457 total time=   0.7s
# [CV 1/10; 8/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 10/10; 7/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.453 total time=   0.7s
# [CV 2/10; 8/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 1/10; 8/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.455 total time=   1.3s
# [CV 3/10; 8/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 2/10; 8/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.505 total time=   1.1s
# [CV 4/10; 8/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 3/10; 8/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.418 total time=   1.2s
# [CV 5/10; 8/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 4/10; 8/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.445 total time=   1.2s
# [CV 6/10; 8/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 5/10; 8/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.440 total time=   1.0s
# [CV 7/10; 8/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 6/10; 8/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.443 total time=   1.1s
# [CV 8/10; 8/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 7/10; 8/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.337 total time=   1.1s
# [CV 9/10; 8/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 8/10; 8/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.432 total time=   0.9s
# [CV 10/10; 8/60] START clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 9/10; 8/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.458 total time=   1.1s
# [CV 1/10; 9/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 10/10; 8/60] END clf__C=0.001, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.457 total time=   1.1s
# [CV 2/10; 9/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 1/10; 9/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.482 total time=   0.4s
# [CV 3/10; 9/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 2/10; 9/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.502 total time=   0.4s
# [CV 4/10; 9/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 3/10; 9/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.420 total time=   0.4s
# [CV 5/10; 9/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 4/10; 9/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.463 total time=   0.4s
# [CV 6/10; 9/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 5/10; 9/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.442 total time=   0.4s
# [CV 7/10; 9/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 6/10; 9/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.427 total time=   0.4s
# [CV 8/10; 9/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 7/10; 9/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.342 total time=   0.4s
# [CV 9/10; 9/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 8/10; 9/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.400 total time=   0.4s
# [CV 10/10; 9/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 9/10; 9/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.468 total time=   0.4s
# [CV 1/10; 10/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 10/10; 9/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.483 total time=   0.4s
# [CV 2/10; 10/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 1/10; 10/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.482 total time=   0.4s
# [CV 3/10; 10/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 2/10; 10/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.502 total time=   0.5s
# [CV 4/10; 10/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 3/10; 10/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.422 total time=   0.5s
# [CV 5/10; 10/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 4/10; 10/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.465 total time=   0.5s
# [CV 6/10; 10/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 5/10; 10/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.440 total time=   0.5s
# [CV 7/10; 10/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 6/10; 10/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.430 total time=   0.5s
# [CV 8/10; 10/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 7/10; 10/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.340 total time=   0.5s
# [CV 9/10; 10/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 8/10; 10/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.402 total time=   0.5s
# [CV 10/10; 10/60] START clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 9/10; 10/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.468 total time=   0.6s
# [CV 1/10; 11/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 10/10; 10/60] END clf__C=0.001, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.482 total time=   0.5s
# [CV 2/10; 11/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 2/10; 11/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.485 total time=   3.1s
# [CV 3/10; 11/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 1/10; 11/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.470 total time=   8.2s
# [CV 4/10; 11/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 3/10; 11/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.412 total time=   7.3s
# [CV 5/10; 11/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 4/10; 11/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.457 total time=   6.2s
# [CV 6/10; 11/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 5/10; 11/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.443 total time=   8.6s
# [CV 7/10; 11/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 6/10; 11/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.433 total time=   7.0s
# [CV 8/10; 11/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 8/10; 11/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.398 total time=   6.6s
# [CV 9/10; 11/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 7/10; 11/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.340 total time=   9.0s
# [CV 10/10; 11/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 9/10; 11/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.467 total time=   8.7s
# [CV 1/10; 12/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 10/10; 11/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.483 total time=   8.5s
# [CV 2/10; 12/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 2/10; 12/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.483 total time=   3.2s
# [CV 3/10; 12/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 1/10; 12/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.472 total time=   9.2s
# [CV 4/10; 12/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 3/10; 12/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.413 total time=   8.4s
# [CV 5/10; 12/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 4/10; 12/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.462 total time=   7.1s
# [CV 6/10; 12/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 5/10; 12/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.448 total time=  10.0s
# [CV 7/10; 12/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 6/10; 12/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.432 total time=   8.2s
# [CV 8/10; 12/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 7/10; 12/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.340 total time=  10.4s
# [CV 9/10; 12/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 8/10; 12/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.397 total time=   7.8s
# [CV 10/10; 12/60] START clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 10/10; 12/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.480 total time=   9.9s
# [CV 1/10; 13/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 9/10; 12/60] END clf__C=0.001, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.468 total time=  10.2s
# [CV 2/10; 13/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 1/10; 13/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 3/10; 13/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 2/10; 13/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 4/10; 13/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 3/10; 13/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 5/10; 13/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 4/10; 13/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 6/10; 13/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 5/10; 13/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 7/10; 13/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 6/10; 13/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 8/10; 13/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 7/10; 13/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 9/10; 13/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 8/10; 13/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 10/10; 13/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 9/10; 13/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 1/10; 14/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 10/10; 13/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=5000;, score=nan total time=   0.3s
# [CV 2/10; 14/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 1/10; 14/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 3/10; 14/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 2/10; 14/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 4/10; 14/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 3/10; 14/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 5/10; 14/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 4/10; 14/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 6/10; 14/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 5/10; 14/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 7/10; 14/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 6/10; 14/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 8/10; 14/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 7/10; 14/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 9/10; 14/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 8/10; 14/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 10/10; 14/60] START clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 9/10; 14/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 1/10; 15/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 10/10; 14/60] END clf__C=0.005, clf__penalty=l1, clf__solver=lbfgs, vectorizer__max_features=None;, score=nan total time=   0.3s
# [CV 2/10; 15/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 1/10; 15/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.438 total time=   0.3s
# [CV 3/10; 15/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 2/10; 15/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.478 total time=   0.3s
# [CV 4/10; 15/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 3/10; 15/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.393 total time=   0.3s
# [CV 5/10; 15/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 4/10; 15/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.415 total time=   0.3s
# [CV 6/10; 15/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 5/10; 15/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.388 total time=   0.3s
# [CV 7/10; 15/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 6/10; 15/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.450 total time=   0.4s
# [CV 8/10; 15/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 7/10; 15/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.362 total time=   0.4s
# [CV 9/10; 15/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 8/10; 15/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.362 total time=   0.3s
# [CV 10/10; 15/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 9/10; 15/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.338 total time=   0.3s
# [CV 1/10; 16/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 10/10; 15/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.413 total time=   0.3s
# [CV 2/10; 16/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 1/10; 16/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.437 total time=   0.4s
# [CV 3/10; 16/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 2/10; 16/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.478 total time=   0.4s
# [CV 4/10; 16/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 3/10; 16/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.393 total time=   0.4s
# [CV 5/10; 16/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 4/10; 16/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.417 total time=   0.4s
# [CV 6/10; 16/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 5/10; 16/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.388 total time=   0.4s
# [CV 7/10; 16/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 6/10; 16/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.450 total time=   0.4s
# [CV 8/10; 16/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 7/10; 16/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.362 total time=   0.4s
# [CV 9/10; 16/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 8/10; 16/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.362 total time=   0.4s
# [CV 10/10; 16/60] START clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None
# [CV 9/10; 16/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.337 total time=   0.4s
# [CV 1/10; 17/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 10/10; 16/60] END clf__C=0.005, clf__penalty=l1, clf__solver=liblinear, vectorizer__max_features=None;, score=0.413 total time=   0.4s
# [CV 2/10; 17/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 1/10; 17/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.433 total time=   3.9s
# [CV 3/10; 17/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 3/10; 17/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.398 total time=   3.2s
# [CV 4/10; 17/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 4/10; 17/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.412 total time=   4.8s
# [CV 5/10; 17/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 2/10; 17/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.493 total time=  12.7s
# [CV 6/10; 17/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 6/10; 17/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.385 total time=   1.0s
# [CV 7/10; 17/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 7/10; 17/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.338 total time=   1.0s
# [CV 8/10; 17/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 8/10; 17/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.383 total time=   3.7s
# [CV 9/10; 17/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 9/10; 17/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.412 total time=   3.0s
# [CV 10/10; 17/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000
# [CV 5/10; 17/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.362 total time=  15.9s
# [CV 1/10; 18/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 1/10; 18/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.432 total time=   4.6s
# [CV 2/10; 18/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 2/10; 18/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.492 total time=   3.1s
# [CV 3/10; 18/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 10/10; 17/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=5000;, score=0.403 total time=  17.1s
# [CV 4/10; 18/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 3/10; 18/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.393 total time=   3.5s
# [CV 5/10; 18/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 4/10; 18/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.410 total time=   5.6s
# [CV 6/10; 18/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 6/10; 18/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.385 total time=   1.1s
# [CV 7/10; 18/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 7/10; 18/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.337 total time=   1.0s
# [CV 8/10; 18/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 8/10; 18/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.383 total time=   4.2s
# [CV 9/10; 18/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 9/10; 18/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.410 total time=   3.3s
# [CV 10/10; 18/60] START clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None
# [CV 5/10; 18/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.362 total time=  18.4s
# [CV 1/10; 19/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 1/10; 19/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.458 total time=   0.9s
# [CV 2/10; 19/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 2/10; 19/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.515 total time=   0.9s
# [CV 3/10; 19/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 3/10; 19/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.418 total time=   0.9s
# [CV 4/10; 19/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 4/10; 19/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.470 total time=   0.9s
# [CV 5/10; 19/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 5/10; 19/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.442 total time=   0.8s
# [CV 6/10; 19/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 6/10; 19/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.438 total time=   0.9s
# [CV 7/10; 19/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 7/10; 19/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.353 total time=   0.9s
# [CV 8/10; 19/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 8/10; 19/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.397 total time=   0.8s
# [CV 9/10; 19/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 9/10; 19/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.452 total time=   0.8s
# [CV 10/10; 19/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 10/10; 19/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.492 total time=   0.8s
# [CV 1/10; 20/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 1/10; 20/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.455 total time=   1.6s
# [CV 2/10; 20/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 2/10; 20/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.515 total time=   1.4s
# [CV 3/10; 20/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 3/10; 20/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.420 total time=   1.5s
# [CV 4/10; 20/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 4/10; 20/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.468 total time=   1.6s
# [CV 5/10; 20/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 5/10; 20/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.443 total time=   1.5s
# [CV 6/10; 20/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 10/10; 18/60] END clf__C=0.005, clf__penalty=l1, clf__solver=saga, vectorizer__max_features=None;, score=0.403 total time=  20.8s
# [CV 7/10; 20/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 6/10; 20/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.445 total time=   1.5s
# [CV 8/10; 20/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 7/10; 20/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.355 total time=   1.6s
# [CV 9/10; 20/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 8/10; 20/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.397 total time=   1.5s
# [CV 10/10; 20/60] START clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 9/10; 20/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.457 total time=   1.7s
# [CV 1/10; 21/60] START clf__C=0.005, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 10/10; 20/60] END clf__C=0.005, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.487 total time=   1.6s
# [CV 2/10; 21/60] START clf__C=0.005, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 1/10; 21/60] END clf__C=0.005, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.452 total time=   0.4s
# ...
# [CV 4/10; 55/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.410 total time=   1.9s
# [CV 6/10; 55/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 5/10; 55/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.458 total time=   1.9s
# [CV 7/10; 55/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 6/10; 55/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.465 total time=   1.9s
# [CV 8/10; 55/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 7/10; 55/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.370 total time=   1.9s
# [CV 9/10; 55/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 8/10; 55/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.368 total time=   1.7s
# [CV 10/10; 55/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000
# [CV 9/10; 55/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.455 total time=   1.9s
# [CV 1/10; 56/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 10/10; 55/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=5000;, score=0.518 total time=   1.9s
# [CV 2/10; 56/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 1/10; 56/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.457 total time=   3.7s
# [CV 3/10; 56/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 2/10; 56/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.500 total time=   3.8s
# [CV 4/10; 56/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 3/10; 56/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.440 total time=   3.6s
# [CV 5/10; 56/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 4/10; 56/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.418 total time=   3.5s
# [CV 6/10; 56/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 5/10; 56/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.443 total time=   3.6s
# [CV 7/10; 56/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 6/10; 56/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.460 total time=   3.4s
# [CV 8/10; 56/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 7/10; 56/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.370 total time=   3.7s
# [CV 9/10; 56/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 8/10; 56/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.378 total time=   3.6s
# [CV 10/10; 56/60] START clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None
# [CV 9/10; 56/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.465 total time=   3.6s
# [CV 1/10; 57/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 10/10; 56/60] END clf__C=0.1, clf__penalty=l2, clf__solver=lbfgs, vectorizer__max_features=None;, score=0.503 total time=   3.6s
# [CV 2/10; 57/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 1/10; 57/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.465 total time=   0.8s
# [CV 3/10; 57/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 2/10; 57/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.527 total time=   0.8s
# [CV 4/10; 57/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 3/10; 57/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.423 total time=   0.7s
# [CV 5/10; 57/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 4/10; 57/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.423 total time=   0.8s
# [CV 6/10; 57/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 5/10; 57/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.458 total time=   0.7s
# [CV 7/10; 57/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 6/10; 57/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.457 total time=   0.7s
# [CV 8/10; 57/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 7/10; 57/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.353 total time=   0.7s
# [CV 9/10; 57/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 8/10; 57/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.383 total time=   0.7s
# [CV 10/10; 57/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000
# [CV 9/10; 57/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.422 total time=   0.7s
# [CV 1/10; 58/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 10/10; 57/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=5000;, score=0.523 total time=   0.8s
# [CV 2/10; 58/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 1/10; 58/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.470 total time=   1.0s
# [CV 3/10; 58/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 2/10; 58/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.515 total time=   1.3s
# [CV 4/10; 58/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 3/10; 58/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.438 total time=   1.1s
# [CV 5/10; 58/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 4/10; 58/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.420 total time=   1.3s
# [CV 6/10; 58/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 5/10; 58/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.448 total time=   1.2s
# [CV 7/10; 58/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 6/10; 58/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.462 total time=   1.3s
# [CV 8/10; 58/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 7/10; 58/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.375 total time=   1.2s
# [CV 9/10; 58/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 8/10; 58/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.383 total time=   1.1s
# [CV 10/10; 58/60] START clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None
# [CV 9/10; 58/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.432 total time=   1.3s
# [CV 1/10; 59/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 10/10; 58/60] END clf__C=0.1, clf__penalty=l2, clf__solver=liblinear, vectorizer__max_features=None;, score=0.517 total time=   1.1s
# [CV 2/10; 59/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 1/10; 59/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.467 total time=   6.4s
# [CV 3/10; 59/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 2/10; 59/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.495 total time=   6.0s
# [CV 4/10; 59/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 4/10; 59/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.420 total time=   5.9s
# [CV 5/10; 59/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 3/10; 59/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.418 total time=   6.5s
# [CV 6/10; 59/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 5/10; 59/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.455 total time=   6.6s
# [CV 7/10; 59/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 6/10; 59/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.462 total time=   7.1s
# [CV 8/10; 59/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 7/10; 59/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.367 total time=   6.0s
# [CV 9/10; 59/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 8/10; 59/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.373 total time=   6.5s
# [CV 10/10; 59/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000
# [CV 9/10; 59/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.457 total time=   6.3s
# [CV 1/10; 60/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 10/10; 59/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=5000;, score=0.502 total time=   6.4s
# [CV 2/10; 60/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 1/10; 60/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.462 total time=   7.2s
# [CV 3/10; 60/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 2/10; 60/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.495 total time=   6.8s
# [CV 4/10; 60/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 3/10; 60/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.437 total time=   7.3s
# [CV 5/10; 60/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 4/10; 60/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.417 total time=   6.8s
# [CV 6/10; 60/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 5/10; 60/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.445 total time=   7.7s
# [CV 7/10; 60/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 6/10; 60/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.450 total time=   7.9s
# [CV 8/10; 60/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 7/10; 60/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.387 total time=   7.2s
# [CV 9/10; 60/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 8/10; 60/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.372 total time=   7.2s
# [CV 10/10; 60/60] START clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None
# [CV 9/10; 60/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.470 total time=   7.0s
# [CV 10/10; 60/60] END clf__C=0.1, clf__penalty=l2, clf__solver=saga, vectorizer__max_features=None;, score=0.508 total time=   7.1s
# /opt/homebrew/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 100 fits failed out of a total of 600.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 100 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/pipeline.py", line 427, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/homebrew/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.33216667 0.33216667 0.38716667 0.38966667
#  0.43833333 0.439      0.44283333 0.44316667 0.43883333 0.4395
#         nan        nan 0.40383333 0.40366667 0.402      0.40066667
#  0.4435     0.44416667 0.4455     0.445      0.439      0.44
#         nan        nan 0.421      0.42133333 0.413      0.41283333
#  0.4465     0.44866667 0.445      0.44683333 0.44116667 0.4445
#         nan        nan 0.4215     0.4215     0.41566667 0.41566667
#  0.44683333 0.45       0.44733333 0.4505     0.44533333 0.44466667
#         nan        nan 0.42716667 0.42716667 0.42283333 0.42283333
#  0.44516667 0.4435     0.4435     0.446      0.4415     0.44416667]
#   warnings.warn(
# Best Parameters: {'clf__C': 0.05, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vectorizer__max_features': None}
# Best Mean Accuracy: 0.4505
